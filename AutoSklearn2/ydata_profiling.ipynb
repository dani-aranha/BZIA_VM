# %%
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv('./data/penguins_clean.csv')
profile = ProfileReport(df, title='Penguins Clean')

# %%
profile.to_file("./html/Penguins_Clean.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
