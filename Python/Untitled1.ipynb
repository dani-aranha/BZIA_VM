# %% [markdown]
# B

# %%
from decimal import Decimal, getcontext

# %%
round(14/3, 2)
# Out:
# 4.67

# %%
int(14/3)
# Out:
# 4

# %%
int(14/3)
# Out:
# 4

# %%
14/3
# Out:
# 4.666666666666667

# %%
int('1ab', 16)
# Out:
# 427

# %%
smileybytes = bytes('😀', 'utf-8' )
smil

# %%
bytes(4)
# Out:
# b'\x00\x00\x00\x00'
