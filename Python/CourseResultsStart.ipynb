# %% [markdown]
# # Guess the Courses!
#
# Below are the marks for the 1st three courses you have completed. Each should be treated as a seperate array (currently they are actually lists). No need to put these into a df as each list is sorted by that individual course. i.e. you could not assume that c1[0], c2[0], or c3[0] is the same person.
# Do some analysys on the 3 courses and then guess which course is c1, c2, or c3. (Introduction to BI, SQL for Analysts, Python for DS)
#
# Perform some EDA on each series and at least a boxplot for each class.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
c1 = [99, 99, 98, 97, 96, 96, 95, 94, 92, 91, 85, 79, 78, 73, 67, 65, 63]
c2 = [99, 95, 95, 95, 94, 92, 91, 88, 87, 85, 82, 80, 78, 72, 72, 68, 65]
c3 = [98, 98, 97, 95, 95, 95, 95, 94, 91, 89, 89, 88, 84, 77, 72, 68, 67]
