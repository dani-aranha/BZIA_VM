# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %% [raw]
# import sys
# print(sys.version)
#
# import pandas as pd
# print(pd.__version__)
#
# import numpy as np
# print(np.__version__)

# %%
df = pd.read_csv('./data/synthetic_customer_data.csv')

# %%
profile = ProfileReport(df)
profile.to_file("./data/customer_data.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df = pd.read_csv('./data/synthetic_customer_data_with_correlations.csv')
df.head()
profile = ProfileReport(df)
profile.to_file('./data/customer_data_with_correlations.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df.head()
df.describe().T
# Out:
#                  count          mean           std      min         25%  \
# age              950.0     43.951579     14.991735    18.00     31.0000
# purchase_amount  950.0    500.831389    285.662302    14.59    241.6025
# annual_income    950.0  49194.787347  29423.899417 -8028.86  23352.2425
# loyalty_score    904.0     50.189259     21.225962    -9.23     34.7050
#
#                        50%         75%        max
# age                 44.000     56.0000      69.00
# purchase_amount    507.430    739.3925     997.95
# annual_income    50988.260  73699.9275  112387.22
# loyalty_score       49.405     67.1925     103.49

# %%
df = pd.read_csv('./data/synthetic_customer_data_with_outliers_skew.csv')

profile = ProfileReport(df)
profile.to_file('./data/customer_data_with_outliers_skew.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
