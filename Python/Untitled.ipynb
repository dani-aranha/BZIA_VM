# %%
20 / 4
# Out:
# 5.0

# %%
4*4
# Out:
# 16

# %%
4 ** 4.0
# Out:
# 256.0

# %%
int(14/3)
# Out:
# 4

# %%
14/3
# Out:
# 4.666666666666667

# %%
round(14/3, 3)
# Out:
# 4.667

# %%
round(1.2 - 1.0, 3)
# Out:
# 0.2

# %%
int('100', 2)
# Out:
# 4

# %%
bytes(4)
# Out:
# b'\x00\x00\x00\x00'

# %%
Bytes('utf-8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Bytes('utf-8')
#
# NameError: name 'Bytes' is not defined
