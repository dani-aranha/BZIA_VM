# %%
# %pip install --upgrade jupyterlab
# Out:
# ...
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---------------------------------------  12.3/12.4 MB 110.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 55.3 MB/s  0:00:00
# ...
#   Attempting uninstall: jupyterlab
#     Found existing installation: jupyterlab 4.4.10
#     Uninstalling jupyterlab-4.4.10:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'c:\\users\\biauser\\miniconda3\\envs\\analyst-lab\\scripts\\jupyter-lab.exe'
# Consider using the `--user` option or check the permissions.
