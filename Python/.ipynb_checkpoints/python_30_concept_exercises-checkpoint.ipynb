# %%
Name = 'Danielle'
Age = 41
Height = 154
is_student = True
print(f"My name is {Name}, I am {Age} years old and have {Height} cm and student status:{is_student}.")

# %% [markdown]
# **Question:** What concept is used here?

# %% [markdown]
# **Answer:** f-string (formatted string literal)

# %%
numbers = [1, 2, 3, 4, 5]
squares = [n**2 for n in numbers]
print(squares)

# %% [markdown]
# **Question:** What concept is used to create squares?

# %% [markdown]
# **Answer:** List comprehension

# %%
def greet(name):
    return f"Hello, {name}"
print(greet("Alice"))

# %% [markdown]
# **Question:** What concept is demonstrated here?

# %% [markdown]
# **Answer:** Function definition and return statement

# %%
try:
    x = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero")

# %% [markdown]
# **Question:** What concept is used to handle errors?

# %% [markdown]
# **Answer:** Exception handling with try-except block

# %%
with open("file.txt", "r") as f:
    content = f.read()
    print(content)

# %% [markdown]
# **Question:** What concept is used to manage the file resource?

# %% [markdown]
# **Answer:** Context manager (with statement)

# %%
add = lambda a, b: a + b
print(add(3, 5))

# %% [markdown]
# **Question:** What concept is used to define add?

# %% [markdown]
# **Answer:** Lambda function

# %%
for i in range(5):
    print(i)

# %% [markdown]
# **Question:** What concept is shown here?

# %% [markdown]
# **Answer:** For loop

# %%
i = 0
while i < 5:
    print(i)
    i += 1

# %% [markdown]
# **Question:** What concept is shown here?

# %% [markdown]
# **Answer:** While loop

# %%
fruits = ["apple", "banana"]
fruits.append("orange")
print(fruits)

# %% [markdown]
# **Question:** What concept is used to add an item?

# %% [markdown]
# **Answer:** List append method

# %%
student = {"name": "Alice", "age": 20}
print(student["name"])

# %% [markdown]
# **Question:** What concept is used here?

# %% [markdown]
# **Answer:** Dictionary key access

# %%
text = "Python"
print(text.upper())

# %% [markdown]
# **Question:** What concept is used here?

# %% [markdown]
# **Answer:** String method (upper)

# %%
nums = [1, 2, 3]
nums.pop()
print(nums)

# %% [markdown]
# **Question:** What concept is used here?

# %% [markdown]
# **Answer:** List pop method

# %%
nums = [1, 2, 3]
print(len(nums))

# %% [markdown]
# **Question:** What concept is used here?

# %% [markdown]
# **Answer:** Built-in len() function

# %%
import math
print(math.sqrt(16))

# %% [markdown]
# **Question:** What concept is used here?

# %% [markdown]
# **Answer:** Importing and using a module

# %%
class Dog:
    def __init__(self, name):
        self.name = name
d = Dog("Buddy")
print(d.name)

# %% [markdown]
# **Question:** What concept is used here?

# %% [markdown]
# **Answer:** Class and object instantiation

# %%
nums = [1, 2, 3]
nums[0] = 10
print(nums)

# %% [markdown]
# **Question:** What concept is shown here?

# %% [markdown]
# **Answer:** List mutability

# %%
tuple_data = (1, 2, 3)
print(tuple_data[1])

# %% [markdown]
# **Question:** What concept is shown here?

# %% [markdown]
# **Answer:** Tuple indexing

# %%
set_data = {1, 2, 3}
set_data.add(4)
print(set_data)

# %% [markdown]
# **Question:** What concept is shown here?

# %% [markdown]
# **Answer:** Set add method

# %%
nums = [1, 2, 3]
print(sum(nums))

# %% [markdown]
# **Question:** What concept is shown here?

# %% [markdown]
# **Answer:** Built-in sum() function

# %%
nums = [1, 2, 3]
print(max(nums))

# %% [markdown]
# **Question:** What concept is shown here?

# %% [markdown]
# **Answer:** Built-in max() function

# %%
nums = [1, 2, 3]
print(min(nums))

# %% [markdown]
# **Question:** What concept is shown here?

# %% [markdown]
# **Answer:** Built-in min() function

# %%
nums = [1, 2, 3]
print(sorted(nums, reverse=True))

# %% [markdown]
# **Question:** What concept is shown here?

# %% [markdown]
# **Answer:** sorted() function with reverse parameter

# %%
nums = [1, 2, 3]
print([x for x in nums if x % 2 == 0])

# %% [markdown]
# **Question:** What concept is shown here?

# %% [markdown]
# **Answer:** List comprehension with condition

# %%
nums = [1, 2, 3]
print([x*x for x in nums])

# %% [markdown]
# **Question:** What concept is shown here?

# %% [markdown]
# **Answer:** List comprehension for squares

# %%
nums = [1, 2, 3]
print(any(x > 2 for x in nums))

# %% [markdown]
# **Question:** What concept is shown here?

# %% [markdown]
# **Answer:** any() function with generator expression

# %%
nums = [1, 2, 3]
print(all(x > 0 for x in nums))

# %% [markdown]
# **Question:** What concept is shown here?

# %% [markdown]
# **Answer:** all() function with generator expression

# %%
nums = [1, 2, 3]
print(list(map(lambda x: x*2, nums)))

# %% [markdown]
# **Question:** What concept is shown here?

# %% [markdown]
# **Answer:** map() with lambda

# %%
nums = [1, 2, 3]
print(list(filter(lambda x: x % 2 == 0, nums)))

# %% [markdown]
# **Question:** What concept is shown here?

# %% [markdown]
# **Answer:** filter() with lambda

# %%
from functools import reduce
nums = [1, 2, 3]
print(reduce(lambda a,b: a+b, nums))

# %% [markdown]
# **Question:** What concept is shown here?

# %% [markdown]
# **Answer:** reduce() with lambda

# %%
nums = [1, 2, 3]
print([x for x in nums if x > 1])

# %% [markdown]
# **Question:** What concept is shown here?

# %% [markdown]
# **Answer:** List comprehension filtering values
