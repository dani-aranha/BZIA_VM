# %% [markdown]
# # Python Functions Tutorial
# A comprehensive guide to understanding and using functions in Python

# %% [markdown]
# ## 1. Introduction to Functions
#
# **What is a Function?**
#
# A function is a reusable block of code that performs a specific task. Functions help you:
# - Organize your code
# - Avoid repetition
# - Make code more readable, extensible and reusable.
# - Break complex problems into smaller pieces

# %%
'''
If I have technical points to document, I tend to
document them in THIS docstring as they are for anyone
using or modifying the code
'''
vGreet = 'Outer scope' #vGreet outside the function (scope)

# Basic function syntax
def greet(vGreet = vGreet):      #vGreet inside the function (scope)
    """
    This function prints a greeting message
    it prints the message, you input!
    When you call greet, input your message:
    
    -->greet ('Put Greeting Here')
    
    """
    return vGreet

# %%
# Calling the function
greet('Inner Scope')
# Out:
# 'Inner Scope'

# %%
vGreet
# Out:
# 'Outer scope'

# %% [markdown]
# ## 2. Functions with Parameters
#
# Parameters allow you to pass information into functions. They make functions more flexible and reusable.

# %%
def greet_person(name):
    """Greets a person by name"""
    print(f"Hello, {name}!")

greet_person("Alice")
greet_person("Bob")

# %%
# Multiple parameters
def add_numbers(a, b):
    """Adds two numbers together"""
    result = a + b
    print(f"{a} + {b} = {result}")

add_numbers(5, 3)
add_numbers(10, 20)

# %% [markdown]
# ## 3. Return Values
#
# The `return` statement sends a value back to the caller. This allows you to use the result of a function elsewhere.

# %%
def multiply(x, y):
    """Multiplies two numbers and returns the result"""
    return x * y

# Store the returned value
product = multiply(4, 7)
print(f"The product is: {product}")

# Use return value directly
print(f"5 times 6 equals: {multiply(5, 6)}")

# %% [markdown]
# ## 4. Default Parameters
#
# Default parameters have preset values that are used if no argument is provided when calling the function.

# %%
def power(base, exponent=2):
    """Raises base to the power of exponent (default is 2)"""
    return base ** exponent

print(power(3))      # Uses default exponent of 2: 3^2 = 9
print(power(3, 3))   # Uses provided exponent: 3^3 = 27
print(power(2, 4))   # 2^4 = 16

# %% [markdown]
# ## 5. Keyword Arguments
#
# Keyword arguments allow you to specify arguments by parameter name, making your code more readable and order-independent.

# %%
def describe_pet(animal_type, pet_name):
    """Displays information about a pet"""
    print(f"I have a {animal_type} named {pet_name}.")

# Positional arguments
describe_pet("dog", "Buddy")

# Keyword arguments (order doesn't matter)
describe_pet(pet_name="Whiskers", animal_type="cat")

# %% [markdown]
# ## 6. Return Multiple Values
#
# Python functions can return multiple values using tuples.

# %%
def get_min_max(numbers):
    """Returns both minimum and maximum values from a list"""
    return min(numbers), max(numbers)

values = [3, 7, 2, 9, 1, 5]
minimum, maximum = get_min_max(values)
print(f"Min: {minimum}, Max: {maximum}")

# %% [markdown]
# ## 7. Docstrings
#
# Docstrings are special strings that document what a function does. They appear right after the function definition and can be accessed using `help()` or the `__doc__` attribute.

# %%
def calculate_area(length, width):
    """
    Calculate the area of a rectangle.
    
    Parameters:
    length (float): The length of the rectangle
    width (float): The width of the rectangle
    
    Returns:
    float: The area of the rectangle
    """
    return length * width

# Access the docstring
print(calculate_area.__doc__)
# Or use: help(calculate_area)

# %% [markdown]
# ## 8. Variable Scope
#
# Scope determines where variables can be accessed.
# - **Local scope**: Variables defined inside a function
# - **Global scope**: Variables defined outside functions

# %%
global_var = "I'm global"

def demonstrate_scope():
    local_var = "I'm local"
    print(global_var)  # Can access global variable
    print(local_var)   # Can access local variable

demonstrate_scope()
# print(local_var)  # This would cause an error!

# %% [markdown]
# ---
# # PRACTICE EXERCISES
# ---

# %% [markdown]
# ### Exercise 1: Temperature Converter
#
# Write a function called `celsius_to_fahrenheit` that:
# - Takes one parameter: temperature in Celsius
# - Converts it to Fahrenheit using: F = (C × 9/5) + 32
# - Returns the Fahrenheit temperature

# %%
# Your code here:
def celsius_to_fahrenheit(celsius):
    return celsius, (celsius * 9/5) + 32

# Test your function (uncomment to test):
#print(celsius_to_fahrenheit(2))    # Should print 32.0
#print(celsius_to_fahrenheit(0))  # Should print 212.0
#print(f'The Fahrenheit difference from freezing today is {celsius_to_fahrenheit(2)-celsius_to_fahrenheit(0):.2}f')
celsius_to_fahrenheit(2)[0],celsius_to_fahrenheit(2)[1]
print(f'{celsius_to_fahrenheit(2)[0]} Fahreheit: {celsius_to_fahrenheit(2)[0]} Celcius')
temp_c = -2
print(f'The fahrenheit difference from freezing today is {celsius_to_fahrenheit(temp_c)[1] - 32:.2}f')

print(f'{0} Fahrenheit: {0} Celsius')
#print(f'{celsius_to_fahrenheit(0)} Fahreheit: {0} Celcius')
# Out:
# 2 Fahreheit: 2 Celcius
# The fahrenheit difference from freezing today is -3.6f
# 0 Fahrenheit: 0 Celsius

# %% [markdown]
# ### Exercise 2: Is Even?
#
# Write a function called `is_even` that:
# - Takes one parameter: a number
# - Returns `True` if the number is even, `False` otherwise
# - Hint: Use the modulo operator `%`

# %%
# Your code here:
def is_even(number):
    '''
    Return a bool True if even, False if not
    '''
    oe = 'odd'
    if (number % 2 == 0) == True:
        oe= 'even'
    return number, number % 2 == 0, oe
        

# Test your function (uncomment to test):
#print(is_even(4))   # Should print True
#print(is_even(7))   # Should print False

n = 3
#is_even(n)[0], is_even(n)[1]
#print(f'{is_even(n)[0]} is even: {is_even(n)[1]}')

#now - return number is "even" or number is "odd"


print(f"{is_even(n)[0]} is {is_even(n)[2]}")
# Out:
# 3 is odd

# %%
def is_even(number):
    oe = number % 2
    return number, oe, 'odd' if oe else 'even'

n = 2
print(f"{is_even(n)[0]} is {is_even(n)[2]}")
# Out:
# 2 is even

# %% [markdown]
# ### Exercise 3: Find Maximum
#
# Write a function called `find_max` that:
# - Takes three parameters: three numbers
# - Returns the largest of the three numbers
# - Do NOT use the built-in `max()` function

# %%
# Your code here:

def find_max(a, b, c):
    '''
    Function to return the largest number among a, b, and c
    '''
    lst = [a, b, c]
    largest = lst[0]  # start with the first element

    for i in lst:
        if i > largest:
            largest = i
    return largest

# Test your function:
print(find_max(5, 12, 8))   # Should print 12
print(find_max(3, 3, 1))    # Should print 3
# Out:
# 12
# 3

# %%
def find_max(a, b, c):
    # Start by assuming 'a' is the largest
    largest = a
    
    # Compare with b
    if b > largest:
        largest = b
    
    # Compare with c
    if c > largest:
        largest = c
    
    return largest

# Test your function
print(find_max(5, 12, 8))  # Should print 12
print(find_max(3, 3, 1))   # Should print 3
# Out:
# 12
# 3

# %% [markdown]
# ### Exercise 4: Count Vowels
#
# Write a function called `count_vowels` that:
# - Takes one parameter: a string
# - Returns the number of vowels (a, e, i, o, u) in the string
# - Hint: Use a loop and check if each character is in "aeiou"

# %%
# Your code here:
def count_vowels(text):
    pass

# Test your function (uncomment to test):
# print(count_vowels("hello"))        # Should print 2
# print(count_vowels("python"))       # Should print 1
# print(count_vowels("aeiou"))        # Should print 5

# %% [markdown]
# ### Exercise 5: Calculate Grade
#
# Write a function called `calculate_grade` that:
# - Takes one parameter: a score (0-100)
# - Returns a letter grade based on:
#   - 90-100: "A"
#   - 80-89: "B"
#   - 70-79: "C"
#   - 60-69: "D"
#   - Below 60: "F"

# %%
# Your code here:
def calculate_grade(score):
    pass

# Test your function (uncomment to test):
# print(calculate_grade(95))  # Should print "A"
# print(calculate_grade(82))  # Should print "B"
# print(calculate_grade(55))  # Should print "F"

# %% [markdown]
# ### Exercise 6: List Statistics
#
# Write a function called `list_stats` that:
# - Takes one parameter: a list of numbers
# - Returns three values: sum, average, and count of numbers
# - Hint: Use `len()` to get count, `sum()` to get total

# %%
# Your code here:
def list_stats(numbers):
    pass

# Test your function (uncomment to test):
# total, avg, count = list_stats([1, 2, 3, 4, 5])
# print(f"Sum: {total}, Average: {avg}, Count: {count}")
# Should print: Sum: 15, Average: 3.0, Count: 5

# %% [markdown]
# ### BONUS Exercise 7: Fibonacci
#
# Write a function called `fibonacci` that:
# - Takes one parameter: n (a positive integer)
# - Returns the nth Fibonacci number
# - Fibonacci sequence: 0, 1, 1, 2, 3, 5, 8, 13, 21...
# - Each number is the sum of the previous two

# %%
# Your code here:
def fibonacci(n):
    pass

# Test your function (uncomment to test):
# print(fibonacci(0))   # Should print 0
# print(fibonacci(1))   # Should print 1
# print(fibonacci(6))   # Should print 8
# print(fibonacci(10))  # Should print 55

# %% [markdown]
# ---
# ## End of Tutorial
#
# Great job working through this tutorial! Functions are a fundamental building block in Python programming. Keep practicing and experimenting with different types of functions to strengthen your understanding.
