# %% [markdown]
# ## Anscombe's quartet
# [Wiki Entry](https://en.wikipedia.org/wiki/Anscombe%27s_quartet)

# %%
# ---------------------------------------------------------
# Anscombe's Quartet – Data, Stats, and Visualizations
# ---------------------------------------------------------

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# ---------------------------------------------------------
# 1. Define the dataset
# ---------------------------------------------------------

data = {
    "x1": [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5],
    "y1": [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68],
    "x2": [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5],
    "y2": [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74],
    "x3": [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5],
    "y3": [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73],
    "x4": [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8],
    "y4": [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89],
}

df = pd.DataFrame(data)
df
# Out:
#     x1     y1  x2    y2  x3     y3  x4     y4
# 0   10   8.04  10  9.14  10   7.46   8   6.58
# 1    8   6.95   8  8.14   8   6.77   8   5.76
# 2   13   7.58  13  8.74  13  12.74   8   7.71
# 3    9   8.81   9  8.77   9   7.11   8   8.84
# 4   11   8.33  11  9.26  11   7.81   8   8.47
# 5   14   9.96  14  8.10  14   8.84   8   7.04
# 6    6   7.24   6  6.13   6   6.08   8   5.25
# 7    4   4.26   4  3.10   4   5.39  19  12.50
# 8   12  10.84  12  9.13  12   8.15   8   5.56
# 9    7   4.82   7  7.26   7   6.42   8   7.91
# 10   5   5.68   5  4.74   5   5.73   8   6.89

# %%
# ---------------------------------------------------------
# 2. Descriptive statistics for each dataset
# ---------------------------------------------------------

stats = {}

for i in range(1, 5):
    x = df[f"x{i}"]
    y = df[f"y{i}"]
    stats[f"Set {i}"] = {
        "x_mean": x.mean(),
        "y_mean": y.mean(),
        "x_variance": x.var(),
        "y_variance": y.var(),
        "correlation": x.corr(y),
    }

pd.DataFrame(stats)
# Out:
#                  Set 1      Set 2      Set 3      Set 4
# x_mean        9.000000   9.000000   9.000000   9.000000
# y_mean        7.500909   7.500909   7.500000   7.500909
# x_variance   11.000000  11.000000  11.000000  11.000000
# y_variance    4.127269   4.127629   4.122620   4.123249
# correlation   0.816421   0.816237   0.816287   0.816521

# %%
stats
# Out:
# {'Set 1': {'x_mean': np.float64(9.0),
#   'y_mean': np.float64(7.500909090909093),
#   'x_variance': 11.0,
#   'y_variance': 4.127269090909091,
#   'correlation': np.float64(0.81642051634484)},
#  'Set 2': {'x_mean': np.float64(9.0),
#   'y_mean': np.float64(7.50090909090909),
#   'x_variance': 11.0,
#   'y_variance': 4.127629090909091,
#   'correlation': np.float64(0.8162365060002428)},
#  'Set 3': {'x_mean': np.float64(9.0),
#   'y_mean': np.float64(7.5),
#   'x_variance': 11.0,
#   'y_variance': 4.12262,
#   'correlation': np.float64(0.8162867394895984)},
#  'Set 4': {'x_mean': np.float64(9.0),
#   'y_mean': np.float64(7.500909090909091),
#   'x_variance': 11.0,
#   'y_variance': 4.12324909090909,
#   'correlation': np.float64(0.8165214368885028)}}

# %%
# ---------------------------------------------------------
# 3. Visualizations
# ---------------------------------------------------------

sns.set_theme(style="whitegrid")
