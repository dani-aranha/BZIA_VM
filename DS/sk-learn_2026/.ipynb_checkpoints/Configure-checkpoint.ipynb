# %%
#conda install scikit-learn numpy pandas matplotlib seaborn --update-deps
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# ...
# Solving environment: \ Channels:
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
# done
#
# ## Package Plan ##
#
#   environment location: C:\Users\biauser\anaconda3\envs\ds312
#
#   added / updated specs:
#     - matplotlib
#     - numpy
#     - pandas
#     - scikit-learn
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aom-3.12.1                 |       h00a0c3c_0         5.5 MB
#     dav1d-1.2.1                |       h2bbff1b_0         672 KB
#     freeglut-3.8.0             |       hfcef157_0         117 KB
#     freetype-2.14.1            |       hfbffc0b_0         514 KB
#     fribidi-1.0.16             |       haf45083_0          70 KB
#     harfbuzz-12.3.0            |       h3ef6528_1         1.1 MB
# ...

# %%
#conda update --all
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\biauser\anaconda3\envs\ds312
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cython-3.2.2               |  py312h02ab6af_0         3.1 MB
#     dataclasses-0.8            |     pyh6d0b6a4_7           8 KB
#     filetype-1.2.0             |  py312haa95532_1         981 KB
#     jsonschema-4.25.1          |  py312haa95532_0         216 KB
#     jupyter-lsp-2.3.0          |  py312haa95532_0         115 KB
#     jupyter_client-8.8.0       |  py312haa95532_0         254 KB
#     jupyter_server-2.17.0      |  py312haa95532_1         604 KB
#     jupyter_server_terminals-0.5.3|  py312haa95532_1          25 KB
#     jupyterlab-4.5.0           |  py312haa95532_1         7.9 MB
# ...

# %%
import sklearn
