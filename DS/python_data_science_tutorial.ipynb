# %% [markdown]
# # Python Data Science Tutorial
# Inspired by Jake VanderPlas's [Python Data Science Handbook](https://github.com/jakevdp/PythonDataScienceHandbook).
#
# Welcome to this interactive tutorial! We'll explore essential tools for data science using Python:
# - NumPy for numerical computing
# - pandas for data manipulation
# - Matplotlib for visualization
# - scikit-learn for machine learning
#
# Let's vibe code: experiment, visualize, and learn by doing!

# %% [markdown]
# ## Setup
# Make sure you have the following libraries installed:
# ```bash
# pip install numpy pandas matplotlib scikit-learn
# ```

# %% [markdown]
# ## NumPy Basics
# NumPy provides fast array operations and is the foundation for scientific computing in Python.

# %%
import numpy as np

# Create an array
arr = np.array([1, 2, 3, 4, 5])
print('Array:', arr)

# Perform operations
print('Mean:', np.mean(arr))
print('Squared:', arr ** 2)

# %% [markdown]
# ### Practice Exercise
# Create a NumPy array of numbers from 10 to 50, then:
# - Compute the sum
# - Compute the standard deviation
# - Multiply all elements by 2

# %% [markdown]
# ## pandas DataFrames
# pandas is great for handling tabular data.

# %%
import pandas as pd

# Create a DataFrame
data = {'Name': ['Alice', 'Bob', 'Charlie'], 'Score': [85, 90, 95]}
df = pd.DataFrame(data)
print(df)

# Describe the data
print(df.describe())

# %% [markdown]
# ### Practice Exercise
# Create a DataFrame with columns: `Product`, `Price`, `Quantity`. Then:
# - Calculate total revenue (Price * Quantity)
# - Find the average price

# %% [markdown]
# ## Visualization with Matplotlib
# Matplotlib helps us create visualizations to understand data.

# %%
import matplotlib.pyplot as plt

# Simple plot
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y)
plt.title('Sine Wave')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.show()

# %% [markdown]
# ### Practice Exercise
# Plot a cosine wave and customize the color and line style.

# %% [markdown]
# ## Machine Learning with scikit-learn
# scikit-learn provides simple and efficient tools for predictive data analysis.

# %%
from sklearn.linear_model import LinearRegression

# Example: Simple Linear Regression
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([2, 4, 6, 8, 10])

model = LinearRegression()
model.fit(X, y)
print('Coefficient:', model.coef_)
print('Intercept:', model.intercept_)

# %% [markdown]
# ### Practice Exercise
# Create a dataset with X = [10, 20, 30, 40, 50] and y = [15, 25, 35, 45, 55]. Fit a linear regression model and predict y for X = 60.
