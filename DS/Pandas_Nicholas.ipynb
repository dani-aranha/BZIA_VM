# %% [markdown]
# ⭐ Optimized Prompt for M365 Copilot
# Full Multi‑Notebook Curriculum Generator
#
# Prompt
# Create a complete multi‑notebook curriculum based on the following video:
# https://youtu.be/tRKeLrwfUgU
# The curriculum must contain one Jupyter Notebook () per major section of the video.
# All explanations, examples, and exercises in the notebooks must be based on the material from this reference page:
# https://scipy-lectures.org/intro/language/python_language.html
#
# Curriculum Requirements
# 1. Identify the Structure
# •     Extract the major sections or chapters from the video.
# •     For each section, create a separate Jupyter Notebook.
# 2. Notebook Requirements
# Each notebook must include:
# •     A clear title matching the video section
# •     A short overview of the learning objectives
# •     Explanatory Markdown cells
# •     Python code examples aligned with the SciPy Lectures content
# •     Output descriptions (text only if execution is not possible)
# •     At least three practice exercises
# •     A separate solutions section
# •     A short summary and “Next Steps” section
# 3. Style & Pedagogy
# •     Assume the learner is a beginner.
# •     Use simple, readable Python.
# •     Include comments inside code cells.
# •     Use Markdown headings and subheadings for clarity.
# •     Ensure each notebook stands alone but also fits into the overall curriculum.
# 4. Output Format
# •     Present each notebook’s content directly in the chat in a clean, copy‑ready format.
# •     Separate notebooks clearly with headings such as:
# Notebook 1 — Title
# Notebook 2 — Title
# etc.
# 5. Workflow
# 1.     Identify and list all major sections of the video.
# 2.     Wait for my confirmation or edits to the section list.
# 3.     Generate the full curriculum, one notebook per section.
# 4.     Present the notebooks in order.
#
# First Task
# List the major sections of the video so I can confirm them before you generate the notebooks.
#
# Note
#
# I had one follow up prompt on order:
# This doesn't seem to follow the order of the youtube video, Pandas for Data Science in 20 Minutes | Python Crash Course. Can I get this material in that order to work as a supplement for the video?

# %% [markdown]
# # Pandas for Data Science — Enhanced Curriculum
#
# ## Table of Contents
# 1. Introduction to Pandas
# 2. Installing and Importing Pandas
# 3. Creating Series and DataFrames
# 4. Reading and Writing Data
# 5. Inspecting and Summarizing Data
# 6. Selecting and Filtering Data
# 7. Data Cleaning and Handling Missing Values
# 8. Sorting and Grouping
# 9. Applying Functions and Operations
# 10. Merging, Joining, and Concatenating
# 11. Basic Plotting with Pandas
# 12. Final Mini-Project

# %% [markdown]
# # Section 1 — Introduction to Pandas
#
# ## Learning Objectives
# - Understand what Pandas is and why it’s important.
# - Learn the key features of Pandas for data manipulation.

# %% [markdown]
# ### Explanation
# Pandas is a Python library for data analysis and manipulation. It provides two main data structures:
# - **Series**: One-dimensional labeled array.
# - **DataFrame**: Two-dimensional labeled data structure (like a spreadsheet).
#
# Why use Pandas?
# - Easy to load, clean, and analyze data.
# - Built-in functions for filtering, grouping, and aggregating.
# - Supports multiple file formats (CSV, Excel, JSON).

# %%
# Example: Import Pandas and check version
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.3

# %% [markdown]
# ### Practice Exercises
# 1. What are the two main data structures in Pandas?
# 2. Why is Pandas useful for data science?
# 3. Import Pandas and print its version.

# %% [markdown]
# ### Solutions
# 1. Series and DataFrame.
# 2. Pandas simplifies data manipulation and integrates with scientific libraries.
# 3.
# ```python
# import pandas as pd
# print(pd.__version__)
# ```

# %% [markdown]
# # Section 2 — Installing and Importing Pandas
#
# ## Learning Objectives
# - Install Pandas using pip.
# - Import Pandas and verify installation.

# %% [markdown]
# ### Explanation
# To install Pandas:
# ```
# pip install pandas
# ```
# To import:
# ```python
# import pandas as pd
# ```

# %%
# Example: Import Pandas
import pandas as pd
print(f"Pandas v.{pd.__version__} imported successfully!")
# Out:
# Pandas v.2.3.3 imported successfully!

# %% [markdown]
# # Section 3 — Creating Series and DataFrames
#
# ## Learning Objectives
# - Create Series and DataFrames from lists and dictionaries.

# %%
# Example: Create a Series
s = pd.Series([10, 20, 30])
print(s)

# Example: Create a DataFrame
data = {'Name': ['Alice', 'Bob'], 'Age': [25, 30]}
df = pd.DataFrame(data)
print(df)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %% [markdown]
# ### Exercises
# 1. Create a Series of 5 numbers.
# 2. Create a DataFrame with columns: Country, Population.
# 3. Add a new column to the DataFrame.

# %% [markdown]
# # Section 4 — Reading and Writing Data
#
# ## Learning Objectives
# - Read CSV files into DataFrames.
# - Write DataFrames to CSV.

# %%
# Example: Read CSV
df = pd.read_csv('./countries.csv')
print(df.head())

# Example: Write CSV
df.to_csv('./countries.csv', index=False)
# Out:
#    Country  Population    GDP
# 0      USA         331  21000
# 1   Canada          38   1800
# 2  Germany          83   4000
# 3   France          67   3000
# 4    Japan         126   5000

# %% [markdown]
# # Section 5 — Inspecting and Summarizing Data
#
# ## Learning Objectives
# - Use .head(), .info(), .describe() to inspect data.

# %%
# Example: Inspect DataFrame
print(df.head())
print(df.info())
print(df.describe())
# Out:
#    Country  Population    GDP
# 0      USA         331  21000
# 1   Canada          38   1800
# 2  Germany          83   4000
# 3   France          67   3000
# 4    Japan         126   5000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     5 non-null      object
#  1   Population  5 non-null      int64
#  2   GDP         5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes
# None
#        Population          GDP
# count    5.000000      5.00000
# mean   129.000000   6960.00000
# std    117.317944   7937.75787
# min     38.000000   1800.00000
# 25%     67.000000   3000.00000
# 50%     83.000000   4000.00000
# 75%    126.000000   5000.00000
# max    331.000000  21000.00000

# %% [markdown]
# # Section 6 — Selecting and Filtering Data
#
# ## Learning Objectives
# - Select columns and rows.
# - Apply conditions.

# %%
# Example: Select column
print(df['Country'])

# Filter rows
print(df[df['GDP'] > 3000])
# Out:
# 0        USA
# 1     Canada
# 2    Germany
# 3     France
# 4      Japan
# Name: Country, dtype: object
#    Country  Population    GDP
# 0      USA         331  21000
# 2  Germany          83   4000
# 4    Japan         126   5000

# %% [markdown]
# # Section 7 — Data Cleaning and Handling Missing Values
#
# ## Learning Objectives
# - Detect and handle NaN values.

# %%
# Example: Fill NaN
df.fillna(0, inplace=True)

# Drop NaN
df.dropna(inplace=True)

# %% [markdown]
# # Section 8 — Sorting and Grouping
#
# ## Learning Objectives
# - Sort DataFrames.
# - Group and aggregate data.

# %%
# Example: Sort by GDP
print(df.sort_values(by='GDP', ascending=False))

# Group by Country
print(df.groupby('Country')['GDP'].mean())
# Out:
#    Country  Population    GDP
# 0      USA         331  21000
# 4    Japan         126   5000
# 2  Germany          83   4000
# 3   France          67   3000
# 1   Canada          38   1800
# Country
# Canada      1800.0
# France      3000.0
# Germany     4000.0
# Japan       5000.0
# USA        21000.0
# Name: GDP, dtype: float64

# %% [markdown]
# # Section 9 — Applying Functions and Operations
#
# ## Learning Objectives
# - Use apply(), map(), and vectorized operations.

# %%
# Example: Add GDP per Capita
df['GDP per Capita'] = df['GDP'] * 1000 / df['Population']
print(df)
# Out:
#    Country  Population    GDP  GDP per Capita
# 0      USA         331  21000    63444.108761
# 1   Canada          38   1800    47368.421053
# 2  Germany          83   4000    48192.771084
# 3   France          67   3000    44776.119403
# 4    Japan         126   5000    39682.539683

# %% [markdown]
# # Section 10 — Merging, Joining, and Concatenating
#
# ## Learning Objectives
# - Combine multiple DataFrames.

# %%
# Example: Merge two DataFrames
df2 = pd.DataFrame({'Country': ['USA', 'Canada'], 'Continent': ['North America', 'North America']})
merged = pd.merge(df, df2, on='Country')
print(merged)
# Out:
#   Country  Population    GDP  GDP per Capita      Continent
# 0     USA         331  21000    63444.108761  North America
# 1  Canada          38   1800    47368.421053  North America

# %% [markdown]
# # Section 11 — Basic Plotting with Pandas
#
# ## Learning Objectives
# - Create simple plots using Pandas.

# %%
import matplotlib.pyplot as plt

# Example: Plot GDP
df.plot(x='Country', y='GDP', kind='bar')
plt.show()

# %% [markdown]
# # Section 12 — Final Mini-Project
#
# ## Objective
# Analyze `countries.csv`:
# - Load the dataset.
# - Clean missing values.
# - Perform grouping and aggregation.
# - Merge with another dataset.
# - Visualize results using Pandas plotting.
