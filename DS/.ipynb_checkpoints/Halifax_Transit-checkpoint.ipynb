# %%
import numpy as np
import pandas as pd

# Viz
import matplotlib.pyplot as plt
import seaborn as sns

# Pretty plots
plt.style.use('seaborn-v0_8')
sns.set_context('notebook')

# Pandas display
pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 120)

# %%
df = pd.read_csv('C:/data/GitHub/BZIA_VM/DS/Halifax_transit.csv')
df.shape
# Out:
# (1326299, 7)

# %%
path = "Halifax_transit.csv"
f = open(path, "r", encoding= "utf-8")

header_line = f.readline()
print("Raw header line:", header_line)
# Out:
# Raw header line: ﻿OBJECTID,Route_Number,Route_Name,Ridership_Total,Route_Hour,Route_Hour_Description,Route_Date

# %%
header = header_line.strip().split(",")
print("Header list:", header)
print("Number of columns:", len(header))

f.close()
# Out:
# Header list: ['\ufeffOBJECTID', 'Route_Number', 'Route_Name', 'Ridership_Total', 'Route_Hour', 'Route_Hour_Description', 'Route_Date']
# Number of columns: 7

# %%
df.columns
# Out:
# Index(['OBJECTID', 'Route_Number', 'Route_Name', 'Ridership_Total', 'Route_Hour', 'Route_Hour_Description',
#        'Route_Date'],
#       dtype='object')

# %%
df.head()
# Out:
#    OBJECTID Route_Number      Route_Name  Ridership_Total  Route_Hour Route_Hour_Description            Route_Date
# 0         1           10       Dalhousie                8         5.5       5:30am to 5:59am  1/1/2024 10:00:00 AM
# 1         2           22         Armdale                2         5.5       5:30am to 5:59am  1/1/2024 10:00:00 AM
# 2         3           6C  Heritage Hills                5         5.5       5:30am to 5:59am  1/1/2024 10:00:00 AM
# 3         4           90     Larry Uteck                0         5.5       5:30am to 5:59am  1/1/2024 10:00:00 AM
# 4         5            1   Spring Garden               21         6.0       6:00am to 6:29am  1/1/2024 10:00:00 AM

# %%
df.dtypes
# Out:
# OBJECTID                    int64
# Route_Number               object
# Route_Name                 object
# Ridership_Total             int64
# Route_Hour                float64
# Route_Hour_Description     object
# Route_Date                 object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1326299 entries, 0 to 1326298
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   OBJECTID                1326299 non-null  int64
#  1   Route_Number            1326299 non-null  object
#  2   Route_Name              1326299 non-null  object
#  3   Ridership_Total         1326299 non-null  int64
#  4   Route_Hour              1326299 non-null  float64
#  5   Route_Hour_Description  1326299 non-null  object
#  6   Route_Date              1326299 non-null  object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 70.8+ MB

# %%
df.isna().sum()
# Out:
# OBJECTID                  0
# Route_Number              0
# Route_Name                0
# Ridership_Total           0
# Route_Hour                0
# Route_Hour_Description    0
# Route_Date                0
# dtype: int64

# %%
df['Ridership_Total']
# Out:
# 0            8
# 1            2
# 2            5
# 3            0
# 4           21
#           ...
# 1326294      2
# 1326295     13
# 1326296     88
# 1326297     92
# 1326298    295
# Name: Ridership_Total, Length: 1326299, dtype: int64

# %%
r1 = df[df['Route_Number'] =='1']
r1.shape
# Out:
# (28322, 7)

# %%
r1['Ridership_Total'].reset_index(drop=True).head(10)
# Out:
# 0     21
# 1     33
# 2     17
# 3     46
# 4    502
# 5     47
# 6     80
# 7    296
# 8     81
# 9    480
# Name: Ridership_Total, dtype: int64

# %%
r1_numbers = r1["Ridership_Total"].tolist()
r1_numbers[:10]
# Out:
# [21, 33, 17, 46, 502, 47, 80, 296, 81, 480]

# %%
r1_only = r1[["Ridership_Total"]].reset_index(drop=True)
r1_only.head(10)
# Out:
#    Ridership_Total
# 0               21
# 1               33
# 2               17
# 3               46
# 4              502
# 5               47
# 6               80
# 7              296
# 8               81
# 9              480

# %%
r1_sorted = r1.sort_values(["Route_Date", "Route_Hour"])
r1_sorted[["Route_Date", "Route_Hour_Description", "Ridership_Total"]].head(10)
# Out:
#                  Route_Date Route_Hour_Description  Ridership_Total
# 20085  1/1/2024 10:00:00 AM       5:30am to 5:59am               29
# 4      1/1/2024 10:00:00 AM       6:00am to 6:29am               21
# 20100  1/1/2024 10:00:00 AM       6:30am to 6:59am               27
# 20112  1/1/2024 10:00:00 AM       7:00am to 7:29am               42
# 46     1/1/2024 10:00:00 AM       7:30am to 7:59am               33
# 59     1/1/2024 10:00:00 AM       8:00am to 8:29am               17
# 80     1/1/2024 10:00:00 AM       8:30am to 8:59am               46
# 20662  1/1/2024 10:00:00 AM       9:00am to 9:29am               28
# 20678  1/1/2024 10:00:00 AM       9:30am to 9:59am               45
# 228    1/1/2024 10:00:00 AM     10:00am to 10:29am               47

# %%
df["Route_Date"] = pd.to_datetime(df["Route_Date"], errors="coerce")
df["Route_Date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
pd.to_datetime(df["Route_Date"], errors="coerce").dtype
# Out:
# dtype('<M8[ns]')

# %%
df["Route_Date"].isna().sum()  # how many became NaT (if any)
# Out:
# np.int64(0)

# %%
df['Year'] = df['Route_Date'].dt.year
df[['Route_Date', 'Year']].head(5)
# Out:
#            Route_Date  Year
# 0 2024-01-01 10:00:00  2024
# 1 2024-01-01 10:00:00  2024
# 2 2024-01-01 10:00:00  2024
# 3 2024-01-01 10:00:00  2024
# 4 2024-01-01 10:00:00  2024

# %%
df.groupby("Year")["Ridership_Total"].sum()
# Out:
# Year
# 2024    30653970
# 2025    30069008
# 2026      909704
# Name: Ridership_Total, dtype: int64

# %%
df.groupby("Year")["Ridership_Total"].mean()
# Out:
# Year
# 2024    47.332024
# 2025    45.844730
# 2026    39.944849
# Name: Ridership_Total, dtype: float64

# %%
df['Ridership_Total'].sum()
# Out:
# np.int64(61632682)

# %%
df['Ridership_Total'].mean()
# Out:
# np.float64(46.46967388198287)

# %%
df.groupby('Route_Number').sum()
# Out:
#                  OBJECTID                                         Route_Name  Ridership_Total  Route_Hour  \
# Route_Number
# 1             18875417675  Spring GardenSpring GardenSpring GardenSpring ...          5378092    422488.0
# 10             3988938605  DalhousieDalhousieDalhousieDalhousieDalhousieD...          1293395    184462.0
# 10A            4182792383  Dalhousie - Bridge TerminalDalhousie - Bridge ...           280469     56395.5
# 10B           12948381021  Dalhousie - Micmac TerminalDalhousie - Micmac ...           836702    201228.0
# 10C           15156969137  DalhousieDalhousieDalhousieDalhousieDalhousieD...          1369596    243587.0
# ...                   ...                                                ...              ...         ...
# 90            15644771526  Larry UteckLarry UteckLarry UteckLarry UteckLa...          1946035    327386.0
# 91            14245520645  Hemlock RavineHemlock RavineHemlock RavineHeml...           762912    298897.5
# 93             4322207833  Bedford HighwayBedford HighwayBedford HighwayB...           128166     79092.0
# 9A            16174443509  GreystoneGreystoneGreystoneGreystoneGreystoneG...          2700419    363221.0
# 9B            15021211947  Herring CoveHerring CoveHerring CoveHerring Co...          1581333    360591.0
#
#                                          Route_Hour_Description                                         Route_Date
# Route_Number
# 1             6:00am to 6:29am7:30am to 7:59am8:00am to 8:29...  1/1/2024 10:00:00 AM1/1/2024 10:00:00 AM1/1/20...
# 10            5:30am to 5:59am4:30pm to 4:59pm5:00pm to 5:29...  1/1/2024 10:00:00 AM1/8/2024 10:00:00 AM1/8/20...
# 10A           2:00pm to 2:29pm4:00pm to 4:29pm4:30pm to 4:59...  11/19/2024 10:00:00 AM11/19/2024 10:00:00 AM11...
# 10B           12:30pm to 12:59pm1:00pm to 1:29pm1:30pm to 1:...  11/19/2024 10:00:00 AM11/19/2024 10:00:00 AM11...
# 10C           1:00pm to 1:29pm2:30pm to 2:59pm3:00pm to 3:29...  11/19/2024 10:00:00 AM11/19/2024 10:00:00 AM11...
# ...                                                         ...                                                ...
# 90            5:30am to 5:59am6:00am to 6:29am6:30am to 6:59...  1/1/2024 10:00:00 AM1/1/2024 10:00:00 AM1/1/20...
# 91            7:30am to 7:59am8:00am to 8:29am3:30pm to 3:59...  1/1/2024 10:00:00 AM1/1/2024 10:00:00 AM1/8/20...
# 93            4:30pm to 4:59pm5:00pm to 5:29pm5:30pm to 5:59...  1/8/2024 10:00:00 AM1/8/2024 10:00:00 AM1/8/20...
# 9A            10:30am to 10:59am6:00pm to 6:29pm6:30pm to 6:...  1/1/2024 10:00:00 AM1/8/2024 10:00:00 AM1/8/20...
# 9B            4:00pm to 4:29pm4:30pm to 4:59pm5:30pm to 5:59...  1/8/2024 10:00:00 AM1/8/2024 10:00:00 AM1/8/20...
#
# [80 rows x 6 columns]

# %%
#“Which routes are most used?”
df.groupby('Route_Number')['Ridership_Total'].sum()
# Out:
# Route_Number
# 1      5378092
# 10     1293395
# 10A     280469
# 10B     836702
# 10C    1369596
#         ...
# 90     1946035
# 91      762912
# 93      128166
# 9A     2700419
# 9B     1581333
# Name: Ridership_Total, Length: 80, dtype: int64

# %%
df['Route_Number'].nunique()
# Out:
# 80

# %%
len(df['Route_Number'].unique())
# Out:
# 80

# %%
df.groupby('Route_Number')['Ridership_Total'].sum().sort_values(ascending=False).head(10)
# Out:
# Route_Number
# 1     5378092
# 3     5036132
# 2     3549295
# 8     3326258
# 4     3153841
# 9A    2700419
# 5     2674204
# 29    1960863
# 90    1946035
# 7A    1623399
# Name: Ridership_Total, dtype: int64

# %%
Route_mean = df.groupby("Route_Number")["Ridership_Total"].mean()
Route_mean.head
# Out:
# <bound method NDFrame.head of Route_Number
# 1      189.890968
# 10     105.859797
# 10A     61.077744
# 10B     59.260713
# 10C     82.800073
#           ...
# 90      81.430873
# 91      35.257972
# 93      19.445608
# 9A     109.996701
# 9B      69.493869
# Name: Ridership_Total, Length: 80, dtype: float64>

# %%
Route_mean_df = (
    df.groupby("Route_Number", as_index=False)["Ridership_Total"]
      .mean()
      .rename(columns={"Ridership_Total": "ridership_mean"})
      .sort_values("ridership_mean", ascending=False)
)
Route_mean_df.head(10)
# Out:
#    Route_Number  ridership_mean
# 0             1      189.890968
# 32            3      171.828858
# 24            2      123.303630
# 67            8      114.583968
# 39            4      110.571854
# 78           9A      109.996701
# 1            10      105.859797
# 43            5       91.366429
# 4           10C       82.800073
# 75           90       81.430873

# %%
# 1) Normalize
df['Route_Number_norm'] = df['Route_Number'].str.strip().str.upper()
df['Route_Name_norm']   = df['Route_Name'].str.strip().str.upper()

# 2) Distinct pairs (like “distinct rows” of number+name)
RouteNumName = df[['Route_Number_norm', 'Route_Name_norm']].drop_duplicates()

# 3) Count them
RouteNumName.shape[0]   # → should be 91

# str.strip().str.upper() >> Clean text by removing extra spaces and making everything UPPERCASE, 
# so ‘small differences’ don’t create fake distinct values.
# Out:
# 91

# %%
# Distinct counts
df['Route_Number'].nunique()                               # 80
df['Route_Name'].nunique()                                 # 89
df[['Route_Number','Route_Name']].drop_duplicates().shape  # (92, 2)
# Out:
# (92, 2)

# %%
# Case-insensitive distinct pairs
(df.assign(Route_Number_norm=df['Route_Number'].str.strip().str.upper(),
           Route_Name_norm=df['Route_Name'].str.strip().str.upper())
   [['Route_Number_norm','Route_Name_norm']]
   .drop_duplicates()
   .shape)  # → (91, 2)
# Out:
# (91, 2)
