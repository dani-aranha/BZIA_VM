# %% [markdown]
# pandas_hands_on_learning
# January 20, 2026
# 1 ￿ Pandas Hands-On Learning Adventure
# W elcome! This notebook is all about learning by doing . Y ou’ll write code, change things, break
# things, and see what happens. That’s how you really learn!
# 1.1 ￿ The Vibe
# • Experiment freely - change the code and run it again
# • Make mistakes - they’re learning opportunities
# • Observe outcomes - see what each change does
# • Have fun - pandas is powerful and actually pretty cool!
# Let’s dive in! ￿

# %% [markdown]
# 1.2 ￿ Setup - Run This First!
# Every pandas adventure starts with imports. Run this cell to get started:

# %%
import pandas as pd
import numpy as np
import matplotlib .pyplot as plt
print("￿ Ready to rock! Pandas version: ", pd.__version__)
# Out:
# ￿ Ready to rock! Pandas version:  2.3.3

# %% [markdown]
# 1.3 ￿ Level 1: Creating Y our First Data
# Let’s start with a Series - think of it as a fancy list with labels.

# %%
# Create a Series from a list
s=pd.Series([ 1,3,5, np.nan,6,8])
print(s)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# 1.3.1 ￿ Y our T urn! Experiment Time:
# T ry these modifications and see what happens: 1. Change the numbers in the list 2. Add
# more numbers 3. Remove some numbers 4. What does np.nan represent? T ry removing it and
# running again

# %%
s2 = s.replace(3,99)
print(s2)
# Out:
# 0     1.0
# 1    99.0
# 2     5.0
# 3     NaN
# 4     6.0
# 5     8.0
# dtype: float64

# %%
s3 = s.replace({1:30, 3:30})
s3
# Out:
# 0    30.0
# 1    30.0
# 2     5.0
# 3     NaN
# 4     6.0
# 5     8.0
# dtype: float64

# %%
s[s>6] = 100
s
# Out:
# 0      1.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      6.0
# 5    100.0
# dtype: float64

# %%
s.loc[3] = 40
s.loc[4] = 50
s
# Out:
# 0      1.0
# 1      3.0
# 2      5.0
# 3     40.0
# 4     50.0
# 5    100.0
# dtype: float64

# %%
s = pd.Series([10, 20, 30])
s.loc[3] = 40
s.loc[4] = 50

print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s5 = s.drop(4)
s5
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s=pd.Series([ 1,3,5, np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
s6 = s.drop(3)
s6
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 4    6.0
# 5    8.0
# dtype: float64

# %%
s_no_nan = s.dropna()
s_no_nan
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 4    6.0
# 5    8.0
# dtype: float64

# %%
# YOUR PLAYGROUND - Experiment here!
s=pd.Series([ 1,3,5, np.nan,6,8]) # Modify this line!
print(s)
# Try adding this line to see the data type:
print("\nData type:", s.dtype)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64
#
# Data type: float64

# %% [markdown]
# 1.4 ￿ Level 2: DataF rames - Where The Magic Happens
# A DataF rame is like a spreadsheet or a table. It’s what makes pandas powerful!

# %%
# Create a date range
dates=pd.date_range( '20240101 ', periods =6)
print("Our dates: ")
print(dates)
# Out:
# Our dates:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
# Create a DataFrame with random numbers
df=pd.DataFrame(np .random.randn(6,4), index =dates, columns =list('ABCD'))
print(df)
# Out:
#                    A         B         C         D
# 2024-01-01  1.181073 -0.334036  0.454300 -0.275390
# 2024-01-02 -0.082929  0.220998  0.457486  0.545249
# 2024-01-03 -0.326521 -0.033192 -0.466588 -1.726429
# 2024-01-04  0.527434  0.090177 -0.089333 -0.051582
# 2024-01-05 -0.934443  1.465491  0.057698 -0.231529
# 2024-01-06  0.501190 -0.502282  0.371352 -0.125199

# %% [markdown]
# 1.4.1 ￿ Y our T urn! Play With DataF rames:
# Experiments to try: 1. Change periods=6 toperiods=10 - what happens? 2. Change the
# column names from 'ABCD' to something else like 'WXYZ' 3. Change the dimensions: try (10, 3)
# instead of (6, 4) (but watch out - rows and columns must match!)

# %%
# YOUR PLAYGROUND
dates=pd.date_range( '20240101 ', periods =10) # Try changing periods!
df=pd.DataFrame(np .random.randn(10,3), index =dates, columns =list('XYZ')) 
#␣Experiment here!
print(df)
# Out:
#                    X         Y         Z
# 2024-01-01  0.493976  1.491457  0.301052
# 2024-01-02  1.028473 -1.202181 -1.486213
# 2024-01-03 -0.829901  1.895950 -0.012531
# 2024-01-04  0.372922 -0.044751  3.460295
# 2024-01-05 -0.569157 -1.496535 -0.645947
# 2024-01-06  0.172638  0.832251  1.302148
# 2024-01-07 -0.046509  0.798963 -0.924055
# 2024-01-08  0.185467 -0.204580 -0.161973
# 2024-01-09  0.737790  1.479779 -0.156466
# 2024-01-10  1.454571  0.652398 -1.106137

# %% [markdown]
# 1.4.2 ￿ Let’s Create a More Interesting DataF rame!

# %%
# Create a DataFrame with mixed data types
df2=pd.DataFrame({
'A':1.0,
'B': pd.Timestamp( '20240102 '),
'C': pd.Series(1, index=range(4), dtype ='float32'),
'D': np.array([3]*4, dtype='int32'),
'E':'pandas is cool '
})
print(df2)
# Out:
#      A          B    C  D                E
# 0  1.0 2024-01-02  1.0  3  pandas is cool
# 1  1.0 2024-01-02  1.0  3  pandas is cool
# 2  1.0 2024-01-02  1.0  3  pandas is cool
# 3  1.0 2024-01-02  1.0  3  pandas is cool

# %% [markdown]
# 1.4.3 ￿ Experiment Challenge:
# T ry modifying: 1. Change the text in column ‘E’ to something else 2. Change the number 3 in
# column ‘D’ to a different number 3. Change the date in column ‘B’ 4. Add a new column ‘F’ with
# your own data!

# %%
# YOUR PLAYGROUND - Get creative!
df2=pd.DataFrame({
'A':1.0,
'B': pd.Timestamp( '20250102 '),
'C': pd.Series(1, index=range(4), dtype ='float32'),
'D': np.array([10]*4, dtype='int32'),
'E':'pandas is one of the hardest think! ',
'X': pd.Series('lov', index=range(4), dtype = 'object')    
})
print(df2)
print("\nData types: ")
print(df2.dtypes)
# Out:
#      A          B    C   D                                     E    X
# 0  1.0 2025-01-02  1.0  10  pandas is one of the hardest think!   lov
# 1  1.0 2025-01-02  1.0  10  pandas is one of the hardest think!   lov
# 2  1.0 2025-01-02  1.0  10  pandas is one of the hardest think!   lov
# 3  1.0 2025-01-02  1.0  10  pandas is one of the hardest think!   lov
#
# Data types:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E           object
# X           object
# dtype: object

# %% [markdown]
# 1.5 ￿ Level 3: Viewing Y our Data
# Let’s learn how to peek at our data eﬀiciently!

# %%
# First, let's create a bigger dataset to work with
dates=pd.date_range( '20240101 ', periods =12)
df=pd.DataFrame(np .random.randn(12,4), index =dates, columns =['A','B','C','D'])
print("Full DataFrame: ")
print(df)
# Out:
# Full DataFrame:
#                    A         B         C         D
# 2024-01-01  1.716467 -2.498634 -0.624995  0.714623
# 2024-01-02 -0.730168  1.124378 -2.010196 -0.626816
# 2024-01-03 -1.306543  0.977644 -0.490783  0.876568
# 2024-01-04 -0.057095  0.527444  1.930687  0.113669
# 2024-01-05 -1.523009  1.559776 -0.826869 -1.125302
# 2024-01-06  1.371169 -0.637723  0.369314 -0.270237
# 2024-01-07  0.448289  0.401435 -0.317191 -1.231632
# 2024-01-08 -0.313289  1.442302  0.418079 -1.497179
# 2024-01-09 -1.878628  0.796902 -2.039253  0.358046
# 2024-01-10  1.583917  0.189095 -0.923595  1.662818
# 2024-01-11 -0.789360 -0.388732 -0.062327  0.370756
# 2024-01-12 -0.597434  0.534825 -0.621401  0.298569

# %%
# View the first few rows
print("First 5 rows: ")
print(df.head())
# Out:
# First 5 rows:
#                    A         B         C         D
# 2024-01-01  1.716467 -2.498634 -0.624995  0.714623
# 2024-01-02 -0.730168  1.124378 -2.010196 -0.626816
# 2024-01-03 -1.306543  0.977644 -0.490783  0.876568
# 2024-01-04 -0.057095  0.527444  1.930687  0.113669
# 2024-01-05 -1.523009  1.559776 -0.826869 -1.125302

# %%
# View the last few rows
print("Last 3 rows: ")
print(df.tail(23))
# Out:
# Last 3 rows:
#                    A         B         C         D
# 2024-01-01  1.716467 -2.498634 -0.624995  0.714623
# 2024-01-02 -0.730168  1.124378 -2.010196 -0.626816
# 2024-01-03 -1.306543  0.977644 -0.490783  0.876568
# 2024-01-04 -0.057095  0.527444  1.930687  0.113669
# 2024-01-05 -1.523009  1.559776 -0.826869 -1.125302
# 2024-01-06  1.371169 -0.637723  0.369314 -0.270237
# 2024-01-07  0.448289  0.401435 -0.317191 -1.231632
# 2024-01-08 -0.313289  1.442302  0.418079 -1.497179
# 2024-01-09 -1.878628  0.796902 -2.039253  0.358046
# 2024-01-10  1.583917  0.189095 -0.923595  1.662818
# 2024-01-11 -0.789360 -0.388732 -0.062327  0.370756
# 2024-01-12 -0.597434  0.534825 -0.621401  0.298569

# %% [markdown]
# 1.5.1 ￿ Experiment Time:
# T ry these: 1. Change head() tohead(3) orhead(7) - what changes? 2. T ry tail(1) or
# tail(10) - observe the results 3. What happens if you ask for more rows than exist?

# %%
# YOUR PLAYGROUND
print(df.head(17)) # Experiment with different numbers!
print("\n")
#print(df.tail(13)) # Try different numbers here too!
# Out:
#                    A         B         C         D
# 2024-01-01  1.716467 -2.498634 -0.624995  0.714623
# 2024-01-02 -0.730168  1.124378 -2.010196 -0.626816
# 2024-01-03 -1.306543  0.977644 -0.490783  0.876568
# 2024-01-04 -0.057095  0.527444  1.930687  0.113669
# 2024-01-05 -1.523009  1.559776 -0.826869 -1.125302
# 2024-01-06  1.371169 -0.637723  0.369314 -0.270237
# 2024-01-07  0.448289  0.401435 -0.317191 -1.231632
# 2024-01-08 -0.313289  1.442302  0.418079 -1.497179
# 2024-01-09 -1.878628  0.796902 -2.039253  0.358046
# 2024-01-10  1.583917  0.189095 -0.923595  1.662818
# 2024-01-11 -0.789360 -0.388732 -0.062327  0.370756
# 2024-01-12 -0.597434  0.534825 -0.621401  0.298569

# %% [markdown]
# 1.5.2 ￿ Quick Stats About Y our Data

# %%
# Get quick statistics
print("Statistical Summary: ")
print(df.describe().T)
# Out:
# Statistical Summary:
#    count      mean       std       min       25%       50%       75%       max
# A   12.0 -0.172974  1.219072 -1.878628 -0.918656 -0.455361  0.679009  1.716467
# B   12.0  0.335726  1.111010 -2.498634  0.044638  0.531135  1.014328  1.559776
# C   12.0 -0.433211  1.072168 -2.039253 -0.851050 -0.556092  0.045583  1.930687
# D   12.0 -0.029676  0.948293 -1.497179 -0.751437  0.206119  0.456723  1.662818

# %%
# Check the shape (rows, columns)
print("Shape (rows, columns): ", df.shape)
print("Number of rows: ",len(df))
print("Column names: ", df.columns.tolist()) # Converts the Index into a regular Python list (list[str]).
                                             #Useful when you need to modify, append, or iterate more freely.
# Out:
# Shape (rows, columns):  (12, 4)
# Number of rows:  12
# Column names:  ['A', 'B', 'C', 'D']

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %% [markdown]
# 1.6 ￿ Level 4: Selecting Data - The F un Part!
# This is where pandas gets really powerful. Let’s learn how to grab exactly the data we want.

# %%
# Select a single column
print("Just column A: ")
print(df['A'])
# Out:
# Just column A:
# 2024-01-01    1.716467
# 2024-01-02   -0.730168
# 2024-01-03   -1.306543
# 2024-01-04   -0.057095
# 2024-01-05   -1.523009
# 2024-01-06    1.371169
# 2024-01-07    0.448289
# 2024-01-08   -0.313289
# 2024-01-09   -1.878628
# 2024-01-10    1.583917
# 2024-01-11   -0.789360
# 2024-01-12   -0.597434
# Freq: D, Name: A, dtype: float64

# %%
# Select multiple columns
print("Columns A and C: ")
print(df[['A','C']])
# Out:
# Columns A and C:
#                    A         C
# 2024-01-01  1.716467 -0.624995
# 2024-01-02 -0.730168 -2.010196
# 2024-01-03 -1.306543 -0.490783
# 2024-01-04 -0.057095  1.930687
# 2024-01-05 -1.523009 -0.826869
# 2024-01-06  1.371169  0.369314
# 2024-01-07  0.448289 -0.317191
# 2024-01-08 -0.313289  0.418079
# 2024-01-09 -1.878628 -2.039253
# 2024-01-10  1.583917 -0.923595
# 2024-01-11 -0.789360 -0.062327
# 2024-01-12 -0.597434 -0.621401

# %% [markdown]
# 1.6.1 ￿ Y our T urn - Column Selection:
# Experiments: 1. Select different single columns (B, C, or D) 2. T ry selecting 3 columns at once
# 3. What happens if you try to select a column that doesn’t exist?

# %%
# YOUR PLAYGROUND
print(df['C']) # Try different columns!
print("\n")
print(df[['B','D']]) # Select different combinations!
# Out:
# 2024-01-01   -0.624995
# 2024-01-02   -2.010196
# 2024-01-03   -0.490783
# 2024-01-04    1.930687
# 2024-01-05   -0.826869
# 2024-01-06    0.369314
# 2024-01-07   -0.317191
# 2024-01-08    0.418079
# 2024-01-09   -2.039253
# 2024-01-10   -0.923595
# 2024-01-11   -0.062327
# 2024-01-12   -0.621401
# Freq: D, Name: C, dtype: float64
#
#
#                    B         D
# 2024-01-01 -2.498634  0.714623
# 2024-01-02  1.124378 -0.626816
# 2024-01-03  0.977644  0.876568
# 2024-01-04  0.527444  0.113669
# 2024-01-05  1.559776 -1.125302
# 2024-01-06 -0.637723 -0.270237
# 2024-01-07  0.401435 -1.231632
# 2024-01-08  1.442302 -1.497179
# 2024-01-09  0.796902  0.358046
# 2024-01-10  0.189095  1.662818
# 2024-01-11 -0.388732  0.370756
# 2024-01-12  0.534825  0.298569

# %% [markdown]
# 1.6.2 ￿ Slicing Rows - Like Slicing Bread!

# %%
# Select rows by position (slicing)
print("Rows 0 to 3: ")
print(df[0:3])
# Out:
# Rows 0 to 3:
#                    A         B         C         D
# 2024-01-01  1.716467 -2.498634 -0.624995  0.714623
# 2024-01-02 -0.730168  1.124378 -2.010196 -0.626816
# 2024-01-03 -1.306543  0.977644 -0.490783  0.876568

# %%
# Select rows by date range
print("Rows from 2024-01-02 to 2024-01-04: ")
print(df['20240102 ':'20240104 '])
# Out:
# Rows from 2024-01-02 to 2024-01-04:
#                    A         B         C         D
# 2024-01-02 -0.730168  1.124378 -2.010196 -0.626816
# 2024-01-03 -1.306543  0.977644 -0.490783  0.876568
# 2024-01-04 -0.057095  0.527444  1.930687  0.113669

# %% [markdown]
# 1.6.3 ￿ Experiment With Slicing:
# T ry these: 1. Change [0:3] to[5:10] or[2:7] - observe what you get 2. T ry different date
# ranges 3. What happens with [0:100] ? (hint: more than we have!)

# %%
# YOUR PLAYGROUND
print(df[1:4]) # Change the slice!
print("\n")
print(df['20240103 ':'20240110 ']) # Try different dates!
# Out:
#                    A         B         C         D
# 2024-01-02 -0.730168  1.124378 -2.010196 -0.626816
# 2024-01-03 -1.306543  0.977644 -0.490783  0.876568
# 2024-01-04 -0.057095  0.527444  1.930687  0.113669
#
#
#                    A         B         C         D
# 2024-01-03 -1.306543  0.977644 -0.490783  0.876568
# 2024-01-04 -0.057095  0.527444  1.930687  0.113669
# 2024-01-05 -1.523009  1.559776 -0.826869 -1.125302
# 2024-01-06  1.371169 -0.637723  0.369314 -0.270237
# 2024-01-07  0.448289  0.401435 -0.317191 -1.231632
# 2024-01-08 -0.313289  1.442302  0.418079 -1.497179
# 2024-01-09 -1.878628  0.796902 -2.039253  0.358046
# 2024-01-10  1.583917  0.189095 -0.923595  1.662818

# %% [markdown]
# 1.6.4 ￿ Precision Selection with .loc and .iloc

# %%
# .loc uses labels
print("Using .loc (label-based): ")
print(df.loc[dates[ 0]])
# Out:
# Using .loc (label-based):
# A    1.716467
# B   -2.498634
# C   -0.624995
# D    0.714623
# Name: 2024-01-01 00:00:00, dtype: float64

# %%
# .iloc uses integer positions
print("Using .iloc (position-based): ")
print(df.iloc[3]) # Gets the 4th row (0-indexed)
# Out:
# Using .iloc (position-based):
# A   -0.057095
# B    0.527444
# C    1.930687
# D    0.113669
# Name: 2024-01-04 00:00:00, dtype: float64

# %%
# Selecting specific rows and columns with .loc
print("Specific rows and columns with .loc: ")
print(df.loc[dates[ 0]:dates[ 3], ['A','B']])
# Out:
# Specific rows and columns with .loc:
#                    A         B
# 2024-01-01  1.716467 -2.498634
# 2024-01-02 -0.730168  1.124378
# 2024-01-03 -1.306543  0.977644
# 2024-01-04 -0.057095  0.527444

# %%
# Selecting by position with .iloc
print("Using .iloc with row and column positions: ")
print(df.iloc[3:5,0:2]) # Rows 3-4, columns 0-1
# Out:
# Using .iloc with row and column positions:
#                    A         B
# 2024-01-04 -0.057095  0.527444
# 2024-01-05 -1.523009  1.559776

# %% [markdown]
# 1.6.5 ￿ Master Selection Challenge:
# Y our experiments: 1. Use.iloc[0] to get the first row, then try .iloc[-1] for the last row
#
# 2.Try.iloc[2:8, 1:3] - what do you get?
#
# 3. Use .loc to select rows 2-6 and columns B and D
#
# 5. What’s the difference between .loc and.iloc ?

# %%
# YOUR PLAYGROUND - Get specific!
print(df.iloc[0]) # Experiment with positions!
# Out:
# A    1.716467
# B   -2.498634
# C   -0.624995
# D    0.714623
# Name: 2024-01-01 00:00:00, dtype: float64

# %%
print(df.iloc[-2:]) # Experiment with positions!
# Out:
#                    A         B         C         D
# 2024-01-11 -0.789360 -0.388732 -0.062327  0.370756
# 2024-01-12 -0.597434  0.534825 -0.621401  0.298569

# %%
print(df.iloc[2:8, 1:3]) # Experiment with positions!
# Out:
#                    B         C
# 2024-01-03  0.977644 -0.490783
# 2024-01-04  0.527444  1.930687
# 2024-01-05  1.559776 -0.826869
# 2024-01-06 -0.637723  0.369314
# 2024-01-07  0.401435 -0.317191
# 2024-01-08  1.442302  0.418079

# %%
print(df.loc[dates[0]:dates[ -1], ['A','B']]) # Try different combinations!
# Out:
#                    A         B
# 2024-01-01  1.716467 -2.498634
# 2024-01-02 -0.730168  1.124378
# 2024-01-03 -1.306543  0.977644
# 2024-01-04 -0.057095  0.527444
# 2024-01-05 -1.523009  1.559776
# 2024-01-06  1.371169 -0.637723
# 2024-01-07  0.448289  0.401435
# 2024-01-08 -0.313289  1.442302
# 2024-01-09 -1.878628  0.796902
# 2024-01-10  1.583917  0.189095
# 2024-01-11 -0.789360 -0.388732
# 2024-01-12 -0.597434  0.534825

# %%
print(df.loc[dates[2]:dates[7], ['B','D']])
# Out:
#                    B         D
# 2024-01-03  0.977644  0.876568
# 2024-01-04  0.527444  0.113669
# 2024-01-05  1.559776 -1.125302
# 2024-01-06 -0.637723 -0.270237
# 2024-01-07  0.401435 -1.231632
# 2024-01-08  1.442302 -1.497179

# %% [markdown]
# 1.7 ￿ Level 5: Boolean Indexing - Finding What Y ou W ant
# This is like asking questions about your data: “Show me all the rows where column A is positive!”

# %%
# Select rows where column A is positive
print("Rows where A > 0: ")
print(df[df['A']>0])
# Out:
# Rows where A > 0:
#                    A         B         C         D
# 2024-01-01  1.716467 -2.498634 -0.624995  0.714623
# 2024-01-06  1.371169 -0.637723  0.369314 -0.270237
# 2024-01-07  0.448289  0.401435 -0.317191 -1.231632
# 2024-01-10  1.583917  0.189095 -0.923595  1.662818

# %%
# Select all positive values (negatives become NaN)
print("All positive values (negatives become NaN): ")
print(df[df>0])
# Out:
# All positive values (negatives become NaN):
#                    A         B         C         D
# 2024-01-01  1.716467       NaN       NaN  0.714623
# 2024-01-02       NaN  1.124378       NaN       NaN
# 2024-01-03       NaN  0.977644       NaN  0.876568
# 2024-01-04       NaN  0.527444  1.930687  0.113669
# 2024-01-05       NaN  1.559776       NaN       NaN
# 2024-01-06  1.371169       NaN  0.369314       NaN
# 2024-01-07  0.448289  0.401435       NaN       NaN
# 2024-01-08       NaN  1.442302  0.418079       NaN
# 2024-01-09       NaN  0.796902       NaN  0.358046
# 2024-01-10  1.583917  0.189095       NaN  1.662818
# 2024-01-11       NaN       NaN       NaN  0.370756
# 2024-01-12       NaN  0.534825       NaN  0.298569

# %% [markdown]
# 1.7.1 ￿ Boolean Magic Experiments:
# T ry these conditions: 1.df[df['A'] < 0] - what do you get? 2. df[df['B'] > 0.5] -
# experiment with different numbers 3. df[df['A'] > df['B']] - comparing columns! 4. Multiple
# conditions: df[(df['A'] > 0) & (df['B'] > 0)]

# %%
# YOUR PLAYGROUND - Ask your data questions!
print("My condition: ")
print(df[df['A']<0]) # Change this condition!
print(df[df['B'] > 0.5])
# Out:
# My condition:
#                    A         B         C         D
# 2024-01-02 -0.730168  1.124378 -2.010196 -0.626816
# 2024-01-03 -1.306543  0.977644 -0.490783  0.876568
# 2024-01-04 -0.057095  0.527444  1.930687  0.113669
# 2024-01-05 -1.523009  1.559776 -0.826869 -1.125302
# 2024-01-08 -0.313289  1.442302  0.418079 -1.497179
# 2024-01-09 -1.878628  0.796902 -2.039253  0.358046
# 2024-01-11 -0.789360 -0.388732 -0.062327  0.370756
# 2024-01-12 -0.597434  0.534825 -0.621401  0.298569
#                    A         B         C         D
# 2024-01-02 -0.730168  1.124378 -2.010196 -0.626816
# 2024-01-03 -1.306543  0.977644 -0.490783  0.876568
# 2024-01-04 -0.057095  0.527444  1.930687  0.113669
# 2024-01-05 -1.523009  1.559776 -0.826869 -1.125302
# 2024-01-08 -0.313289  1.442302  0.418079 -1.497179
# 2024-01-09 -1.878628  0.796902 -2.039253  0.358046
# 2024-01-12 -0.597434  0.534825 -0.621401  0.298569

# %%
# Try multiple conditions:
print(df[(df['A'] > 0) & (df['B'] > 0)])
print(df[df['A'] > df['B']])
# Out:
#                    A         B         C         D
# 2024-01-07  0.448289  0.401435 -0.317191 -1.231632
# 2024-01-10  1.583917  0.189095 -0.923595  1.662818
#                    A         B         C         D
# 2024-01-01  1.716467 -2.498634 -0.624995  0.714623
# 2024-01-06  1.371169 -0.637723  0.369314 -0.270237
# 2024-01-07  0.448289  0.401435 -0.317191 -1.231632
# 2024-01-10  1.583917  0.189095 -0.923595  1.662818

# %% [markdown]
# 1.8 ￿ Level 6: Basic Operations & Stats
# Let’s do some math with our data!

# %%
# Calculate mean for each column
print("Mean of each column: ")
print(df.mean())
# Out:
# Mean of each column:
# A   -0.172974
# B    0.335726
# C   -0.433211
# D   -0.029676
# dtype: float64

# %%
# Calculate mean for each row
print("Mean of each row: ")
print(df.mean(axis =1))
# Out:
# Mean of each row:
# 2024-01-01   -0.173135
# 2024-01-02   -0.560701
# 2024-01-03    0.014221
# 2024-01-04    0.628676
# 2024-01-05   -0.478851
# 2024-01-06    0.208131
# 2024-01-07   -0.174775
# 2024-01-08    0.012478
# 2024-01-09   -0.690733
# 2024-01-10    0.628059
# 2024-01-11   -0.217416
# 2024-01-12   -0.096360
# Freq: D, dtype: float64

# %%
# More statistics!
print("Sum of each column: ")
print(df.sum())
print("\nStandard deviation: ")
print(df.std())
print("\nMax values: ")
print(df.max())
# Out:
# Sum of each column:
# A   -2.075685
# B    4.028713
# C   -5.198530
# D   -0.356117
# dtype: float64
#
# Standard deviation:
# A    1.219072
# B    1.111010
# C    1.072168
# D    0.948293
# dtype: float64
#
# Max values:
# A    1.716467
# B    1.559776
# C    1.930687
# D    1.662818
# dtype: float64

# %% [markdown]
# 1.8.1 ￿ Stats Experiments:
# T ry these methods: 1..min() - find minimum values 2. .median() - find median values 3.
# .std() - standard deviation 4. .count() - count non-null values 5. What happens when you add
# axis=1 to any of these?

# %%
# YOUR PLAYGROUND - Calculate statistics!
print(df.mean()) # Try different methods!
print("\n")

print(df.mean(axis =1)) # Experiment with axis!
# Out:
# A   -0.172974
# B    0.335726
# C   -0.433211
# D   -0.029676
# dtype: float64
#
#
# 2024-01-01   -0.173135
# 2024-01-02   -0.560701
# 2024-01-03    0.014221
# 2024-01-04    0.628676
# 2024-01-05   -0.478851
# 2024-01-06    0.208131
# 2024-01-07   -0.174775
# 2024-01-08    0.012478
# 2024-01-09   -0.690733
# 2024-01-10    0.628059
# 2024-01-11   -0.217416
# 2024-01-12   -0.096360
# Freq: D, dtype: float64

# %%
print(df.min())
print(df.median())
print(df.std())
print(df.count())
print("\n")

print(df.median(axis =1)) # Experiment with axis!
# Out:
# A   -1.878628
# B   -2.498634
# C   -2.039253
# D   -1.497179
# dtype: float64
# A   -0.455361
# B    0.531135
# C   -0.556092
# D    0.206119
# dtype: float64
# A    1.219072
# B    1.111010
# C    1.072168
# D    0.948293
# dtype: float64
# A    12
# B    12
# C    12
# D    12
# dtype: int64
#
#
# 2024-01-01    0.044814
# 2024-01-02   -0.678492
# 2024-01-03    0.192892
# 2024-01-04    0.320556
# 2024-01-05   -0.976085
# 2024-01-06    0.049539
# 2024-01-07    0.042122
# 2024-01-08    0.052395
# 2024-01-09   -0.760291
# 2024-01-10    0.886506
# 2024-01-11   -0.225530
# 2024-01-12   -0.149432
# Freq: D, dtype: float64

# %% [markdown]
# 1.8.2 ￿ Let’s Do Some Math With Our Data

# %%
# Add a number to all values
print("Original: ")
print(df.head(3))
print("\nAdding 10 to everything: ")
print((df+10).head(3))
# Out:
# Original:
#                    A         B         C         D
# 2024-01-01  1.716467 -2.498634 -0.624995  0.714623
# 2024-01-02 -0.730168  1.124378 -2.010196 -0.626816
# 2024-01-03 -1.306543  0.977644 -0.490783  0.876568
#
# Adding 10 to everything:
#                     A          B         C          D
# 2024-01-01  11.716467   7.501366  9.375005  10.714623
# 2024-01-02   9.269832  11.124378  7.989804   9.373184
# 2024-01-03   8.693457  10.977644  9.509217  10.876568

# %%
# Multiply all values
print("Multiplying by 2: ")
print((df*2).head(3))
# Out:
# Multiplying by 2:
#                    A         B         C         D
# 2024-01-01  3.432934 -4.997268 -1.249991  1.429247
# 2024-01-02 -1.460336  2.248755 -4.020393 -1.253632
# 2024-01-03 -2.613087  1.955289 -0.981567  1.753136

# %% [markdown]
# 1.8.3 ￿ Math Experiments:
# T ry these: 1. Subtract 5 from all values: df - 5 2. Divide by 2: df / 2 3. Square all values: df
#  2 4. Get absolute values: df.abs()

# %%
# YOUR PLAYGROUND - Do math!
print((df-5).head())
print((df/2).head())
print((df**2).head())
print(df.abs())
# Try different operations!
# Out:
#                    A         B         C         D
# 2024-01-01 -3.283533 -7.498634 -5.624995 -4.285377
# 2024-01-02 -5.730168 -3.875622 -7.010196 -5.626816
# 2024-01-03 -6.306543 -4.022356 -5.490783 -4.123432
# 2024-01-04 -5.057095 -4.472556 -3.069313 -4.886331
# 2024-01-05 -6.523009 -3.440224 -5.826869 -6.125302
#                    A         B         C         D
# 2024-01-01  0.858234 -1.249317 -0.312498  0.357312
# 2024-01-02 -0.365084  0.562189 -1.005098 -0.313408
# 2024-01-03 -0.653272  0.488822 -0.245392  0.438284
# 2024-01-04 -0.028548  0.263722  0.965343  0.056834
# 2024-01-05 -0.761505  0.779888 -0.413434 -0.562651
#                    A         B         C         D
# 2024-01-01  2.946259  6.243172  0.390619  0.510686
# 2024-01-02  0.533145  1.264225  4.040890  0.392898
# 2024-01-03  1.707056  0.955789  0.240868  0.768372
# 2024-01-04  0.003260  0.278198  3.727552  0.012921
# 2024-01-05  2.319558  2.432900  0.683712  1.266304
# ...

# %% [markdown]
# 1.9 ￿ Level 7: W orking with Missing Data
# Real data is messy! Let’s learn to handle missing values.

# %%
# Create a DataFrame with some missing values
df_missing =df.copy()
df_missing .iloc[0:2,1]=np.nan # Add some NaN values
df_missing .iloc[3:5,2]=np.nan
print("DataFrame with missing values: ")
print(df_missing .head(7))
# Out:
# DataFrame with missing values:
#                    A         B         C         D
# 2024-01-01  1.716467       NaN -0.624995  0.714623
# 2024-01-02 -0.730168       NaN -2.010196 -0.626816
# 2024-01-03 -1.306543  0.977644 -0.490783  0.876568
# 2024-01-04 -0.057095  0.527444       NaN  0.113669
# 2024-01-05 -1.523009  1.559776       NaN -1.125302
# 2024-01-06  1.371169 -0.637723  0.369314 -0.270237
# 2024-01-07  0.448289  0.401435 -0.317191 -1.231632

# %%
# Drop rows with any missing values
print("After dropping rows with NaN: ")
print(df_missing .dropna())
# Out:
# After dropping rows with NaN:
#                    A         B         C         D
# 2024-01-03 -1.306543  0.977644 -0.490783  0.876568
# 2024-01-06  1.371169 -0.637723  0.369314 -0.270237
# 2024-01-07  0.448289  0.401435 -0.317191 -1.231632
# 2024-01-08 -0.313289  1.442302  0.418079 -1.497179
# 2024-01-09 -1.878628  0.796902 -2.039253  0.358046
# 2024-01-10  1.583917  0.189095 -0.923595  1.662818
# 2024-01-11 -0.789360 -0.388732 -0.062327  0.370756
# 2024-01-12 -0.597434  0.534825 -0.621401  0.298569

# %%
# Fill missing values with a number
print("After filling NaN with 0: ")
print(df_missing .fillna(0).head(7))
# Out:
# After filling NaN with 0:
#                    A         B         C         D
# 2024-01-01  1.716467  0.000000 -0.624995  0.714623
# 2024-01-02 -0.730168  0.000000 -2.010196 -0.626816
# 2024-01-03 -1.306543  0.977644 -0.490783  0.876568
# 2024-01-04 -0.057095  0.527444  0.000000  0.113669
# 2024-01-05 -1.523009  1.559776  0.000000 -1.125302
# 2024-01-06  1.371169 -0.637723  0.369314 -0.270237
# 2024-01-07  0.448289  0.401435 -0.317191 -1.231632

# %%
# Fill with the mean of each column
print("After filling with column means: ")
print(df_missing .fillna(df_missing .mean()).head(7))
# Out:
# After filling with column means:
#                    A         B         C         D
# 2024-01-01  1.716467  0.540297 -0.624995  0.714623
# 2024-01-02 -0.730168  0.540297 -2.010196 -0.626816
# 2024-01-03 -1.306543  0.977644 -0.490783  0.876568
# 2024-01-04 -0.057095  0.527444 -0.630235  0.113669
# 2024-01-05 -1.523009  1.559776 -0.630235 -1.125302
# 2024-01-06  1.371169 -0.637723  0.369314 -0.270237
# 2024-01-07  0.448289  0.401435 -0.317191 -1.231632

# %% [markdown]
# 1.9.1 ￿ Missing Data Experiments:
# T ry these:
# 1. Fill with different values: fillna(999) orfillna(-1)
# 2. T ry fillna(method='ffill') - forward fill
# 3. T ry fillna(method='bfill') - backward fill
# 4. Use isna() to see where the NaN values are

# %%
# YOUR PLAYGROUND - Handle missing data!
print(df_missing .fillna(999).head(7)) # Try different strategies!
# Uncomment to see where NaN values are:
# print("\nNaN locations:")
# print(df_missing.isna().head(7))
# Out:
#                    A           B           C         D
# 2024-01-01  1.716467  999.000000   -0.624995  0.714623
# 2024-01-02 -0.730168  999.000000   -2.010196 -0.626816
# 2024-01-03 -1.306543    0.977644   -0.490783  0.876568
# 2024-01-04 -0.057095    0.527444  999.000000  0.113669
# 2024-01-05 -1.523009    1.559776  999.000000 -1.125302
# 2024-01-06  1.371169   -0.637723    0.369314 -0.270237
# 2024-01-07  0.448289    0.401435   -0.317191 -1.231632

# %%
print(df_missing.bfill())
print(df_missing.ffill())
# Out:
#                    A         B         C         D
# 2024-01-01  1.716467  0.977644 -0.624995  0.714623
# 2024-01-02 -0.730168  0.977644 -2.010196 -0.626816
# 2024-01-03 -1.306543  0.977644 -0.490783  0.876568
# 2024-01-04 -0.057095  0.527444  0.369314  0.113669
# 2024-01-05 -1.523009  1.559776  0.369314 -1.125302
# 2024-01-06  1.371169 -0.637723  0.369314 -0.270237
# 2024-01-07  0.448289  0.401435 -0.317191 -1.231632
# 2024-01-08 -0.313289  1.442302  0.418079 -1.497179
# 2024-01-09 -1.878628  0.796902 -2.039253  0.358046
# 2024-01-10  1.583917  0.189095 -0.923595  1.662818
# 2024-01-11 -0.789360 -0.388732 -0.062327  0.370756
# 2024-01-12 -0.597434  0.534825 -0.621401  0.298569
#                    A         B         C         D
# 2024-01-01  1.716467       NaN -0.624995  0.714623
# 2024-01-02 -0.730168       NaN -2.010196 -0.626816
# 2024-01-03 -1.306543  0.977644 -0.490783  0.876568
# 2024-01-04 -0.057095  0.527444 -0.490783  0.113669
# ...

# %% [markdown]
# 1.10 ￿ Level 8: Grouping & Aggregating - Super Powerful!
# This is where pandas really shines. Let’s create some realistic data first.

# %%
# Create a sales dataset
sales_data = pd.DataFrame({
'product': ['A','B','A','B','A','B','A','B'],
'region': ['North','North','South','South','North','North','South','South'],
'sales': [100,150,200,90,110,170,180,95],
'quantity': [10,12,20,8,11,15,18,9]
})
print("Sales Data: ")
print(sales_data)
# Out:
# Sales Data:
#   product region  sales  quantity
# 0       A  North    100        10
# 1       B  North    150        12
# 2       A  South    200        20
# 3       B  South     90         8
# 4       A  North    110        11
# 5       B  North    170        15
# 6       A  South    180        18
# 7       B  South     95         9

# %%
# Group by product and calculate total sales
print("Total sales by product: ")
print(sales_data.groupby('product')['sales'].sum())
# Out:
# Total sales by product:
# product
# A    590
# B    505
# Name: sales, dtype: int64

# %%
# Group by region and calculate mean
print("Average sales by region: ")
print(sales_data.groupby('region')[['sales','quantity']].mean())
# Out:
# Average sales by region:
#          sales  quantity
# region
# North   132.50     12.00
# South   141.25     13.75

# %%
# Multiple aggregations at once!
print("Multiple statistics by product: ")
aggreg = (sales_data.groupby('product')[['sales', 'quantity']].agg(('sum','mean','count','max')))
aggreg
# Out:
# Multiple statistics by product:
#         sales                    quantity
#           sum    mean count  max      sum   mean count max
# product
# A         590  147.50     4  200       59  14.75     4  20
# B         505  126.25     4  170       44  11.00     4  15

# %% [markdown]
# 1.10.1 ￿ Grouping Experiments:
# T ry these: 1. Group by ‘region’ instead of ‘product’ 2. T ry different aggregations: .max() ,
# .min() ,.count() 3. Group by multiple columns: groupby(['product', 'region']) 4. Aggre-
# gate multiple columns: groupby('product')[['sales', 'quantity']].sum()

# %%
# YOUR PLAYGROUND - Group and aggregate!
print(sales_data .groupby( 'region')['sales'].sum())
print(sales_data .groupby( 'product')['sales'].max())# Try different groupings!
print(sales_data .groupby( 'product')['sales'].min())# Try different groupings!
print(sales_data .groupby( 'region')['sales'].count())
# Out:
# region
# North    530
# South    565
# Name: sales, dtype: int64
# product
# A    200
# B    170
# Name: sales, dtype: int64
# product
# A    100
# B     90
# Name: sales, dtype: int64
# region
# North    4
# South    4
# Name: sales, dtype: int64

# %%
# Try this advanced one:
print(sales_data.groupby(['product', 'region'])['sales'].mean())
# Out:
# product  region
# A        North     105.0
#          South     190.0
# B        North     160.0
#          South      92.5
# Name: sales, dtype: float64

# %% [markdown]
# 1.11 ￿ Level 9: Merging & Joining DataF rames
# Combining data from different sources - a crucial skill!

# %%
# Create two DataFrames to merge
df1=pd.DataFrame({
'employee': ['Alice','Bob','Charlie'],
'department': ['Sales','IT','Marketing ']
})
df2=pd.DataFrame({
'employee': ['Alice','Bob','Charlie'],
'salary': [70000,80000,65000]
})
print("DataFrame 1: ")
print(df1)
print("\nDataFrame 2: ")
print(df2)
# Out:
# DataFrame 1:
#   employee  department
# 0    Alice       Sales
# 1      Bob          IT
# 2  Charlie  Marketing
#
# DataFrame 2:
#   employee  salary
# 0    Alice   70000
# 1      Bob   80000
# 2  Charlie   65000

# %%
# Merge the DataFrames
merged=pd.merge(df1, df2, on ='employee')
print("Merged DataFrame: ")
print(merged)
# Out:
# Merged DataFrame:
#   employee  department  salary
# 0    Alice       Sales   70000
# 1      Bob          IT   80000
# 2  Charlie  Marketing    65000

# %%
# YOUR PLAYGROUND - Combine data!
merged=pd.merge(df1, df2, on ='employee') # Try different merge types!
print(merged)

merged_inner = pd.merge(df1, df2, on='employee', how='inner')
merged_inner
# Out:
#   employee  department  salary
# 0    Alice       Sales   70000
# 1      Bob          IT   80000
# 2  Charlie  Marketing    65000
#   employee  department  salary
# 0    Alice       Sales   70000
# 1      Bob          IT   80000
# 2  Charlie  Marketing    65000

# %%
merged_left = pd.merge(df1, df2, on='employee', how='left')
merged_left
# Out:
#   employee  department  salary
# 0    Alice       Sales   70000
# 1      Bob          IT   80000
# 2  Charlie  Marketing    65000

# %%
merged_right = pd.merge(df1, df2, on='employee', how='right')
merged_right
# Out:
#   employee  department  salary
# 0    Alice       Sales   70000
# 1      Bob          IT   80000
# 2  Charlie  Marketing    65000

# %%
# Concatenate DataFrames vertically (stack them)
df3=pd.DataFrame({
'A': ['A4','A5','A6'],
'B': ['B4','B5','B6']
})
df4=pd.DataFrame({
'A': ['A7','A8','A9'],
'B': ['B7','B8','B9']
})
print("Concatenated vertically: ")
print(pd.concat([df3, df4]))
# Out:
# Concatenated vertically:
#     A   B
# 0  A4  B4
# 1  A5  B5
# 2  A6  B6
# 0  A7  B7
# 1  A8  B8
# 2  A9  B9

# %% [markdown]
# 1.11.1 ￿ Merging Experiments:
# T ry these: 1. Add a new employee to one DataF rame but not the other - what happens when
# you merge? 2. T ry different merge types: pd.merge(df1, df2, on='employee', how='left')
# 3. Usehow='right' ,how='inner' , orhow='outer' - observe the differences! 4. Concatenate
# horizontally: pd.concat([df3, df4], axis=1)

# %%
print(pd.concat([df3, df4], axis=1))
# Out:
#     A   B   A   B
# 0  A4  B4  A7  B7
# 1  A5  B5  A8  B8
# 2  A6  B6  A9  B9

# %% [markdown]
# 1.12 ￿ Level 10: String Operations
# W orking with text data is super common. Let’s see how!

# %%
# Create a Series with strings
s=pd.Series([ 'A','B','C','Aaba','Baca', np.nan,'CABA','dog','cat'])
print("Original: ")
print(s)
# Out:
# Original:
# 0       A
# 1       B
# 2       C
# 3    Aaba
# 4    Baca
# 5     NaN
# 6    CABA
# 7     dog
# 8     cat
# dtype: object

# %%
# Convert to lowercase
print("Lowercase: ")
print(s.str.lower())
# Out:
# Lowercase:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
# Convert to uppercase
print("Uppercase: ")
print(s.str.upper())
# Out:
# Uppercase:
# 0       A
# 1       B
# 2       C
# 3    AABA
# 4    BACA
# 5     NaN
# 6    CABA
# 7     DOG
# 8     CAT
# dtype: object

# %%
# String length
print("Length of each string: ")
print(s.str.len())
# Out:
# Length of each string:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    4.0
# 4    4.0
# 5    NaN
# 6    4.0
# 7    3.0
# 8    3.0
# dtype: float64

# %%
# Check if string contains something
print("Contains 'a':")
print(s.str.contains( 'a', na=False))
# Out:
# Contains 'a':
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# 6    False
# 7    False
# 8     True
# dtype: bool

# %% [markdown]
# 1.12.1 ￿ String Operation Experiments:
# T ry these: 1.s.str.capitalize() - capitalize first letter 2. s.str.replace('a', 'X') - replace
# characters 3. s.str.startswith('A') - check if starts with a letter 4. s.str.strip() - remove
# whitespace 5. Change your search in .contains() to look for different patterns

# %%
# YOUR PLAYGROUND - Manipulate strings!
print(s.str.upper()) # Try different string operations!

# Try these:
print(s.str.replace('a', '!'))
print(s.str.startswith('C'))
# Out:
# 0       A
# 1       B
# 2       C
# 3    AABA
# 4    BACA
# 5     NaN
# 6    CABA
# 7     DOG
# 8     CAT
# dtype: object
# 0       A
# 1       B
# 2       C
# 3    A!b!
# 4    B!c!
# 5     NaN
# 6    CABA
# 7     dog
# 8     c!t
# dtype: object
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5      NaN
# 6     True
# 7    False
# 8    False
# dtype: object

# %% [markdown]
# 1.13 ￿ Level 11: Pivot T ables - Excel Users Will Love This!
# Remember pivot tables from Excel? Pandas can do them even better!

# %%
# Create a more complex dataset
df=pd.DataFrame({
'A': ['one','one','two','three']*3,
'B': ['A','B','C']*4,
'C': ['foo','foo','foo','bar','bar','bar']*2,
'D': np.random.randn(12),
'E': np.random.randn(12)
})
print("Dataset: ")
print(df)
# Out:
# Dataset:
#         A  B    C         D         E
# 0     one  A  foo -0.381659  0.017337
# 1     one  B  foo  1.139433 -0.429706
# 2     two  C  foo -1.545293  0.514197
# 3   three  A  bar  0.411110  0.454522
# 4     one  B  bar -1.778498  2.465133
# 5     one  C  bar -0.623256  0.371708
# 6     two  A  foo -1.363995  0.348468
# 7   three  B  foo  1.106017  0.248675
# 8     one  C  foo -0.833264  0.411706
# 9     one  A  bar  1.421999  0.067165
# 10    two  B  bar -0.842942  0.719790
# 11  three  C  bar -1.103512  0.685491

# %%
# Create a pivot table
print("Pivot Table: ")
pivot=pd.pivot_table(df, values ='D', index=['A','B'], columns =['C'])
print(pivot)
# Out:
# Pivot Table:
# C             bar       foo
# A     B
# one   A  1.421999 -0.381659
#       B -1.778498  1.139433
#       C -0.623256 -0.833264
# three A  0.411110       NaN
#       B       NaN  1.106017
#       C -1.103512       NaN
# two   A       NaN -1.363995
#       B -0.842942       NaN
#       C       NaN -1.545293

# %% [markdown]
# 1.13.1 ￿ Pivot T able Experiments:
# T ry these: 1. Change values='D' tovalues='E' 2. Change the index to['C'] 3. T ry
# aggfunc='mean' oraggfunc='count' 4. Addmargins=True to see totals

# %%
# YOUR PLAYGROUND - Create pivot tables!
pivot=pd.pivot_table(df, values ='E', index=['A','B'], columns =['C'])
print(pivot)
# Out:
# C             bar       foo
# A     B
# one   A  1.421999 -0.381659
#       B -1.778498  1.139433
#       C -0.623256 -0.833264
# three A  0.411110       NaN
#       B       NaN  1.106017
#       C -1.103512       NaN
# two   A       NaN -1.363995
#       B -0.842942       NaN
#       C       NaN -1.545293

# %%
# Try this:
pivot = pd.pivot_table(df, values='D', index=['A'], columns=['E'], aggfunc='mean')
print(pivot)
# Out:
# E      -0.429706   0.017337   0.067165   0.248675   0.348468   0.371708  \
# A
# one     1.139433  -0.381659   1.421999        NaN        NaN  -0.623256
# three        NaN        NaN        NaN   1.106017        NaN        NaN
# two          NaN        NaN        NaN        NaN  -1.363995        NaN
#
# E       0.411706   0.454522   0.514197   0.685491   0.719790   2.465133
# A
# one    -0.833264        NaN        NaN        NaN        NaN  -1.778498
# three        NaN    0.41111        NaN  -1.103512        NaN        NaN
# two          NaN        NaN  -1.545293        NaN  -0.842942        NaN

# %% [markdown]
# 1.14 ￿ Level 12: Visualization - See Y our Data!
# A picture is worth a thousand rows of data!

# %%
# Create time series data
ts=pd.Series(np .random.randn(1000), index =pd.date_range( '1/1/2024 ', periods=1000))
ts=ts.cumsum() # Cumulative sum makes it more interesting
# Plot it!
ts.plot(figsize =(12,4))
plt.title('Random Walk Over Time ')
plt.ylabel('Value')
plt.xlabel('Date')
plt.show()

# %%
# Bar plot of our sales data
sales_summary =sales_data .groupby( 'product')['sales'].sum()
sales_summary .plot(kind ='bar', color=['skyblue','coral'])
plt.title('Total Sales by Product ')
plt.ylabel('Sales')
plt.xlabel('Product')
plt.xticks(rotation =0)
plt.show()

# %%
# Multiple columns
dates=pd.date_range( '20240101 ', periods =30)
df_plot =pd.DataFrame(np .random.randn(30,4).cumsum(axis =0),
index=dates,
columns=['A','B','C','D'])
df_plot.plot(figsize =(12,5))
plt.title('Multiple Time Series ')
plt.legend(loc ='best')
plt.show()

# %% [markdown]
# 1.14.1 ￿ Visualization Experiments:
# T ry different plot types: 1.kind='line' - line plot (default) 2. kind='bar' - bar chart 3.
# kind='hist' - histogram 4. kind='box' - box plot 5. kind='scatter' - scatter plot (needs x and
# y) 6. Change colors: color='red' orcolor=['red', 'blue', 'green'] 7. Change figure size:
# figsize=(15, 6)

# %%
# YOUR PLAYGROUND - Make it visual!
df_plot.plot(figsize =(12,5)) # Try different plot types and styles!
plt.title('Your Custom Plot Title ') # Customize this!
plt.show()
# Try a histogram:
# df_plot['A'].plot(kind='hist', bins=20)
# plt.title('Histogram of Column A')
# plt.show()

# %% [markdown]
# 1.15 ￿ Bonus Level: Reading & W riting Files
# In the real world, you’ll often work with files. Let’s practice!

# %%
# Create some sample data
sample_data =pd.DataFrame({
'Name': ['Alice','Bob','Charlie','Diana'],
'Age': [25,30,35,28],
'City': ['New York ','San Francisco ','Chicago','Boston'],
'Salary': [70000,80000,75000,72000]
})
print("Sample data: ")
print(sample_data)
# Out:
# Sample data:
#       Name  Age            City  Salary
# 0    Alice   25       New York    70000
# 1      Bob   30  San Francisco    80000
# 2  Charlie   35         Chicago   75000
# 3    Diana   28          Boston   72000

# %%
# Save to CSV
sample_data .to_csv('my_data.csv ', index=False)
print("￿ Saved to my_data.csv ")
# Read it back
df_from_csv =pd.read_csv( 'my_data.csv ')
print("\nRead from CSV: ")
print(df_from_csv)
# Out:
# ￿ Saved to my_data.csv
#
# Read from CSV:
#       Name  Age            City  Salary
# 0    Alice   25       New York    70000
# 1      Bob   30  San Francisco    80000
# 2  Charlie   35         Chicago   75000
# 3    Diana   28          Boston   72000

# %%
# Save to Excel (requires openpyxl or xlsxwriter)
try: 
    sample_data .to_excel( 'my_data.xlsx ', index=False, sheet_name ='Employees ')
print("￿ Saved to my_data.xlsx ")
# Read it back
    df_from_excel =pd.read_excel( 'my_data.xlsx ')
print("\nRead from Excel: ")
print(df_from_excel)
    except ImportError : 
print("￿ Excel support not installed. Install with: pip install openpyxl ")
# Out:
#   Cell In[126], line 4
#     print("￿ Saved to my_data.xlsx ")
#     ^
# SyntaxError: expected 'except' or 'finally' block

# %% [markdown]
# 1.15.1 ￿ File Operations Experiments:
# T ry these: 1. Modify the sample_data and save it again 2. Read the CSV with
# pd.read_csv('my_data.csv', nrows=2) to read only first 2 rows 3. T ry saving with
# compression: to_csv('data.csv.gz', compression='gzip') 4. Read specific columns:
# pd.read_csv('my_data.csv', usecols=['Name', 'Age'])

# %%
# YOUR PLAYGROUND - Work with files!
# Try reading with different options:
df=pd.read_csv( 'my_data.csv ') # Add your own parameters!

print(df)
# Try reading only specific columns:
# df = pd.read_csv('my_data.csv', usecols=['Name', 'Age'])
# print(df)

# %% [markdown]
# 1.16 ￿ Final Boss Level: Y our Own Mini Project!
# Now it’s your turn to combine everything you’ve learned. Here’s your challenge:
# 1.16.1 ￿ Challenge: Create Y our Own Analysis
# Y our mission: 1. Create a DataF rame with at least 3 columns and 20 rows of data (make it about
# something you’re interested in!) 2. Calculate some statistics (mean, max, min, etc.) 3. Filter the
# data based on some condition 4. Group the data and calculate aggregates 5. Create at least one
# visualization 6. Save your results to a CSV file
# Ideas for your dataset: - Sports statistics (player names, scores, teams) - Book collection (titles,
# authors, ratings, pages) - Music playlist (songs, artists, duration, genre) - Daily expenses (date,
# category , amount, description) - W eather data (date, temperature, humidity , conditions) - Video
# games (title, platform, hours played, rating)
# Use the cells below to build your project!

# %%
# YOUR PROJECT - Step 1: Create your DataFrame
# Example structure to get you started:
# my_df = pd.DataFrame({
# 'column1': [...],
# 'column2': [...],
# 'column3': [...]
# })
# Your code here!

# %%
# YOUR PROJECT - Step 2: Explore and analyze
# Your code here!

# %%
# YOUR PROJECT - Step 3: Filter and group
# Your code here!

# %%
# YOUR PROJECT - Step 4: Visualize
# Your code here!

# %% [markdown]
# # YOUR PROJECT - Step 5: Save your work
# # Your code here!
# 1.17 ￿ Congratulations!
# Y ou’ve made it through the pandas learning adventure! Here’s what you’ve learned:
# ￿ Creating Series and DataF rames
# ￿ Viewing and inspecting data
# ￿ Selecting data (columns, rows, conditions)
# ￿ Boolean indexing
# ￿ Statistical operations
# ￿ Handling missing data
# ￿ Grouping and aggregating
# ￿ Merging and joining
# ￿ String operations
# ￿ Pivot tables
# ￿ Data visualization
# ￿ Reading and writing files

# %% [markdown]
# 1.17.1 ￿ Next Steps:
# • T ry analyzing real datasets (Kaggle has tons of free datasets!)
# • Explore more advanced pandas features
# • Combine pandas with other libraries like scikit-learn for machine learning
# • Build a data dashboard with Streamlit or Plotly Dash
# 1.17.2 ￿ Resources:
# • Oﬀicial Pandas Documentation
# • Pandas Cheat Sheet
# • Real Python Pandas T utorials
# Remember: The best way to learn is by doing. Keep experimenting, keep breaking things, and
# keep building! ￿
# Happy Data Analyzing! ￿￿
