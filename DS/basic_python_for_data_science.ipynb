# %% [markdown]
# # Basic Python for Data Science
# Inspired by Jake VanderPlas's [Python Data Science Handbook](https://github.com/jakevdp/PythonDataScienceHandbook).
#
# This tutorial covers the essential Python concepts you need before diving into data science libraries like NumPy and pandas.
#
# We'll explore:
# - Variables & Data Types
# - Lists & Dictionaries
# - Control Flow (loops, conditionals)
# - Functions
#
# Let's vibe code: learn by experimenting!

# %% [markdown]
# ## Setup
# Make sure you have Python installed. You can check your version:
# ```bash
# python --version
# ```

# %% [markdown]
# ## Variables & Data Types
# Variables store data. Python supports types like integers, floats, strings, and booleans.

# %%
# Examples of variables
x = 10        # integer
y = 3.14      # float
name = 'Alice' # string
is_active = True # boolean

print(x, y, name, is_active)

# %% [markdown]
# ### Practice Exercise
# Create variables:
# - `age` (integer)
# - `height` (float)
# - `city` (string)
# - `student` (boolean)
# Print them all.

# %% [markdown]
# ## Lists & Dictionaries
# Lists store ordered collections, dictionaries store key-value pairs.

# %%
# List example
fruits = ['apple', 'banana', 'cherry']
print(fruits)

# Dictionary example
person = {'name': 'Alice', 'age': 25}
print(person)

# %% [markdown]
# ### Practice Exercise
# Create:
# - A list of 5 colors
# - A dictionary with keys: `brand`, `model`, `year` for a car
# Print both.

# %% [markdown]
# ## Control Flow
# Use conditionals and loops to control program flow.

# %%
# Conditional example
num = 10
if num > 5:
    print('Greater than 5')
else:
    print('Less or equal to 5')

# Loop example
for fruit in ['apple', 'banana', 'cherry']:
    print(fruit)

# %% [markdown]
# ### Practice Exercise
# Write a loop that prints numbers from 1 to 10.
# Add a condition to print 'Even' for even numbers.

# %% [markdown]
# ## Functions
# Functions group reusable code blocks.

# %%
# Function example
def greet(name):
    return f'Hello, {name}!'

print(greet('Alice'))

# %% [markdown]
# ### Practice Exercise
# Write a function `square(num)` that returns the square of a number.
# Test it with 5 and 10.
